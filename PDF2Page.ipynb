# %% [markdown]
# # PDF->Page->Text
#
# This notebook processes PDFs to TXT by splitting the page and performing OCR for each page of the PDF.
#
# ## Outline of the Workflow
# * Mount the notebook to the Google Colab
# * Import Libraries and packages
# * Format params, search, and get files from Google Drive
# * Convert pdf pages to jpeg files
# * Convert jpeg files to txt (string); save them in output_file

# %%
### Modify this cell only
top = '1yei52gRB7vJZCD7RjlTIp0urGnmQCQ20' #1u-uLRd-O0uMpis0r_vPxGcfw3uwv6QUa this is the last PDF that was processed in SecondarySources (2/20/21)
input_dir = '/content/drive/My Drive/AWCA/Colab_notebooks/OCR/OCR_PDF2Page/180_input/'  ##must start and end with a "/"
output_dir = '/content/drive/My Drive/AWCA/Colab_notebooks/OCR/OCR_PDF2Page/180_output/' ##must start and end with a "/"

# %%
from google.colab import auth
auth.authenticate_user()

from googleapiclient.discovery import build
service = build('drive', 'v3')

# %%
# Run this to mount the Notebook in your Google Drive account 
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# One-time installations

# %%
# !pip3 install pdf2image
# !apt-get install poppler-utils 
# !pip3 install pytesseract
# !pip3 install pdf2image
# !sudo apt-get install tesseract-ocr
# !pip install PyPDF2
# Out:
# Collecting pdf2image
#   Downloading https://files.pythonhosted.org/packages/03/62/089030fd16ab3e5c245315d63c80b29250b8f9e4579b5a09306eb7e7539c/pdf2image-1.14.0-py3-none-any.whl
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from pdf2image) (7.0.0)
# Installing collected packages: pdf2image
# Successfully installed pdf2image-1.14.0
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 13 not upgraded.
# Need to get 154 kB of archives.
# After this operation, 613 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 poppler-utils amd64 0.62.0-2ubuntu2.12 [154 kB]
# Fetched 154 kB in 1s (168 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 149406 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_0.62.0-2ubuntu2.12_amd64.deb ...
# Unpacking poppler-utils (0.62.0-2ubuntu2.12) ...
# Setting up poppler-utils (0.62.0-2ubuntu2.12) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Collecting pytesseract
#   Downloading https://files.pythonhosted.org/packages/a0/e6/a4e9fc8a93c1318540e8de6d8d4beb5749b7960388a7c7f27799fc2dd016/pytesseract-0.3.7.tar.gz
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from pytesseract) (7.0.0)
# Building wheels for collected packages: pytesseract
#   Building wheel for pytesseract (setup.py) ... done
#   Created wheel for pytesseract: filename=pytesseract-0.3.7-py2.py3-none-any.whl size=13945 sha256=cb907bb9bf7de71845becebb52fe9ef04d1325f4e93a1c7ec52a9f9d68957797
#   Stored in directory: /root/.cache/pip/wheels/81/20/7e/1dd0daad1575d5260916bb1e9781246430647adaef4b3ca3b3
# Successfully built pytesseract
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.7
# Requirement already satisfied: pdf2image in /usr/local/lib/python3.7/dist-packages (1.14.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from pdf2image) (7.0.0)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 13 not upgraded.
# Need to get 4,795 kB of archives.
# After this operation, 15.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-eng all 4.00~git24-0e00fe6-1.2 [1,588 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-osd all 4.00~git24-0e00fe6-1.2 [2,989 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr amd64 4.00~git2288-10f4998a-2 [218 kB]
# Fetched 4,795 kB in 2s (2,883 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 3.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package tesseract-ocr-eng.
# (Reading database ... 149434 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-eng_4.00~git24-0e00fe6-1.2_all.deb ...
# Unpacking tesseract-ocr-eng (4.00~git24-0e00fe6-1.2) ...
# Selecting previously unselected package tesseract-ocr-osd.
# Preparing to unpack .../tesseract-ocr-osd_4.00~git24-0e00fe6-1.2_all.deb ...
# Unpacking tesseract-ocr-osd (4.00~git24-0e00fe6-1.2) ...
# Selecting previously unselected package tesseract-ocr.
# Preparing to unpack .../tesseract-ocr_4.00~git2288-10f4998a-2_amd64.deb ...
# Unpacking tesseract-ocr (4.00~git2288-10f4998a-2) ...
# Setting up tesseract-ocr-osd (4.00~git24-0e00fe6-1.2) ...
# Setting up tesseract-ocr-eng (4.00~git24-0e00fe6-1.2) ...
# Setting up tesseract-ocr (4.00~git2288-10f4998a-2) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Collecting PyPDF2
#   Downloading https://files.pythonhosted.org/packages/b4/01/68fcc0d43daf4c6bdbc6b33cc3f77bda531c86b174cac56ef0ffdb96faab/PyPDF2-1.26.0.tar.gz (77kB)
#      |████████████████████████████████| 81kB 5.3MB/s
# Building wheels for collected packages: PyPDF2
#   Building wheel for PyPDF2 (setup.py) ... done
#   Created wheel for PyPDF2: filename=PyPDF2-1.26.0-cp37-none-any.whl size=61085 sha256=3248c666123df1c9a22df94ab4c3f521e550912960ab72eda8157d9503dc3507
#   Stored in directory: /root/.cache/pip/wheels/53/84/19/35bc977c8bf5f0c23a8a011aa958acd4da4bbd7a229315c1b7
# Successfully built PyPDF2
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-1.26.0

# %% [markdown]
# Imports

# %%
import os
import json
import csv
import sys
from apiclient.discovery import build  # pip install google-api-python-client
from pdf2image import convert_from_path # the module can convert PDF to a PIL Image object
from PIL import Image
import pytesseract #OCR tool; recognizes the text embedded in images
import sys 
from PyPDF2 import PdfFileReader, PdfFileWriter #the classes can read PDFs, split PDFs, and extract data
from collections import Counter # track the number of occurence of a value
import pandas as pd

# %%
print(pytesseract.get_languages(config=''))
# Out:
# ['osd', 'eng']

# %% [markdown]
# Logging setup

# %%
import logging

logging.basicConfig(level=logging.INFO, format='%(asctime)s %(levelname)s %(threadName)-10s %(message)s',)
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)

# %% [markdown]
# ### Formatting and searching the files

# %%
def iterfiles(name=None, is_folder=None, parent=None, order_by='folder,name,createdTime'):  
    q = []
    if name is not None:
        q.append("name = '%s'" % name.replace("'", "\\'"))
    if is_folder is not None:
        q.append("mimeType %s '%s'" % ('=' if is_folder else '!=', FOLDER))
    if parent is not None:
        q.append("'%s' in parents" % parent.replace("'", "\\'"))
    fields = ['id', 'title', 'mimeType']
    params = {'pageToken': None, 'orderBy': order_by,
              'fields': 'kind, nextPageToken, incompleteSearch, files(id, name, mimeType, md5Checksum, webViewLink, createdTime, modifiedTime, size)'}
    if q:
        params['q'] = ' and '.join(q)
    while True:
        logger.debug('params {}'.format(params))
        response = service.files().list(**params).execute() # searches the files which match **params
        logger.debug('response {}'.format(response))        
        for f in response['files']:
            yield f
        try:
            params['pageToken'] = response['nextPageToken'] # changes the page token of the file to next page token
        except KeyError:
            return

# %% [markdown]
# ### Search all the sub-directories and files inside the initial directory
#
# Uses `iterfiles()`

# %%
def walk(top='root', by_name=False):
    print("walk function is called")
  # Search all the sub-directories and files inside the initial directory
    stack = None
    if not stack:
      # if reading the json file was unsuccessful, check the reasons
        if by_name:
            top, = iterfiles(name=top, is_folder=True) # top as name
        else:
            top = service.files().get(fileId=top).execute() #top as fileId
            if top['mimeType'] != FOLDER:
                raise ValueError('not a folder: %r' % top)
        stack = [([top['name']], top)]
    while stack:
      # if stack is not empty, noting down its information
        logger.info('stack size {}'.format(len(stack)))
        #with open(snapshot_file, 'w') as file:
            #file.write(json.dumps(stack))
        path, top = stack.pop()
        logger.info('dir {}'.format(path))
        dirs, files = is_file = [], []
        for f in iterfiles(parent=top['id']):
            is_file[f['mimeType'] != FOLDER].append(f)
        logger.info('subdirs {} files {}'.format(len(dirs), len(files)))
        yield path, top, dirs, files
        if dirs:
            logger.debug('dirs {}'.format(dirs))
            logger.debug('path {}'.format(path))            
            newstuff = [(path + [d['name']], d) for d in reversed(dirs)]
            logger.debug('extend: {}'.format(newstuff))
            stack.extend(newstuff)

# %% [markdown]
# ### Gives information about a file, including its ID, md5, size, create/modify time.

# %%
def extract_metadata(node):
    md5Checksum = node.get('md5Checksum', 'None')
    size = node.get('size', 'None')
    mimeType = node.get('mimeType', 'None')
    webViewLink = node.get('webViewLink', 'None')
    id = node.get('id', 'None')
    createdTime = node.get('createdTime', 'None')
    modifiedTime = node.get('modifiedTime', 'None')
    name = node.get('name', 'None')
    return id, md5Checksum, size, mimeType, createdTime, modifiedTime

# %% [markdown]
# ### OCR on a Directory
#
# <br/>
#
# #### *Main Idea*:
# Takes in a directory, creates a folder of pages for each PDF/document, and uses OCR to convert all pages to computer text (txt).
#
# <br/>
#
# #### *Imports*:
# * PdfFileReader / PdfFileWriter: Useful for reading and saving PDFs.
# * Counter: Counts the number of each element and stores the each unique as a key with the frequency as dictionary values. Subclass of dict. Used to count frequency of words in a PDF.
#
# <br/>
#
# #### *Outer loop*: Reads in all pdfs from the input directory from `walk()`. Splits a pdf into individual pages which will each be run into the inner for loop. Gets specific information about a file using `extract_metadata` and saves that in a CSV. Creates folder for output if one does not already exist.
# * convert_from_path: takes in a PDF and outputs an image for each page in the PDF
# * img_count: index for inner for loop. Tracks page number for a pdf.
#
# <br/>
#
# #### *Inner `page` loop*: For each page, sets Flag to False. Runs OCR with `pytesseract.[FILENAME]` on the default orientation and all 90-degree rotations: 0°, 90°, 180°, 270°. If any orientation can be read, Flag is set to True and the text of the page is written to output. If none of the rotations generates a proper output, the page is not used.
#
# <br/>

# %%
import random
def dict_common_sum(cntr):
  sum = 0
  for word, freq in cntr.most_common(2):
    sum += freq * 2
  for word, freq in cntr.most_common(5):
    sum += freq * 2
  for word, freq in cntr.most_common(10):
    sum += freq
  return sum

def big_loop(top, csvwriter, maxfiles):   
  fc = 0
  if os.path.isdir(output_dir) == False:
    os.mkdir(output_dir)
  for path, root, dirs, files in walk(top=top, by_name=False):
      # note 'by_name' is currently not used
      dirpath = '/'.join(path)
      id, _, _, mimeType, createdTime, modifiedTime = extract_metadata(root)
      # for directories we use the md5Checksum field to hold the dir count
      md5Checksum = len(dirs) 
      # for directories we use the size field to hold the plain file count
      size = len(files)
      row = [id, md5Checksum, size, mimeType, createdTime, modifiedTime, dirpath]
      csvwriter.writerow(row)
      # we count each dir as a file for the purpose of maxfiles
      fc = fc + 1
      for pdf_index in range(len(files)):
        #Here we conduct page split and put it in a folder
        folder_name = str(files[pdf_index]['id'])+'/' ## This is how google id of the pdf gets to be the folder's name of that pdf
        folder_name_failed = str(id)+'/failed_pages.txt'  ## failed paged are specified in terms of filename and pages
        pdf_numbers = len(files)
        file_name = input_dir[:-1]+'/'+files[pdf_index]['name']
        if ((file_name.endswith('.pdf') == False) and (file_name.endswith('.PDF')== False)):
          continue
        pages = convert_from_path(file_name)
        if os.path.isdir(output_dir+folder_name) == False:
          print("New folder is created")
          os.mkdir(output_dir+folder_name)
        csv_id = []
        csv_text = []
        pdf_name = []
        output_error_file = output_dir +folder_name+ 'failed_pages.txt' #Page the are failed in ocr process specified to pdf name and page number

        '''
        # For debugging purposes. To be used with the other place where page_limit is being used.
        page_limit = 4
        page_curr = 0
        '''

        # Orientation content
        cnt0, cnt1, cnt2, cnt3 = Counter(), Counter(), Counter(), Counter()
        num_to_select = max(min(5, len(pages)), int(0.1 * len(pages)))
        test_pages = random.sample(pages, num_to_select)
        for page_idx, page in enumerate(test_pages):
          img_count = page_idx + 1
          print("image idx: ", img_count)
          save_name = output_dir+folder_name+"page_"+str(img_count)+".jpg"
          page.save(save_name, 'JPEG')
          for i in range(4):
            text = str(((pytesseract.image_to_string(Image.open(save_name)))))
            if (i == 0):
              cnt0.update(text.split())
            if (i == 1):
              cnt1.update(text.split())
            if (i == 2):
              cnt2.update(text.split())
            if (i == 3):
              cnt3.update(text.split())
            page2 = page.rotate(90*(i + 1))
            page2.save(save_name,  'JPEG')
        w_0, w_1, w_2, w_3 = dict_common_sum(cnt0), dict_common_sum(cnt1), dict_common_sum(cnt2), dict_common_sum(cnt3)
        top_orient = max(w_0, w_1, w_2, w_3)
        if w_0 == top_orient:
          k = -1
        if w_1 == top_orient:
          k = 0
        if w_2 == top_orient:
          k = 1
        if w_3 == top_orient:
          k = 2
        
        print("Orientation to be used" + str(k))
        print(cnt0)
        print(len(cnt0))
        print(w_0)
        print(cnt1)
        print(len(cnt1))
        print(w_1)
        print(cnt2)
        print(len(cnt2))
        print(w_2)
        print(cnt3)
        print(len(cnt3))
        print(w_3)

        for page_idx, page in enumerate(pages):
          '''
          # Delete later
          if (page_limit <= page_curr):
            break
          else:
            page_curr += 1
          '''

          img_count = page_idx + 1
          print("image idx: ", img_count)
          save_name = output_dir+folder_name+"page_"+str(img_count)+".jpg"
          page.save(save_name, 'JPEG')
          ##Save the images and csv. 
          #flag = False ##Currently disabling the oritation checker. Replace with a better scheme
          print("Page")
          page2 = page.rotate(90*(k + 1))
          page2.save(save_name,  'JPEG')
          text = str(((pytesseract.image_to_string(Image.open(save_name)))))
          #cnt = Counter()
          #cnt.update(text.split())
          # print(cnt['the'],cnt['de'],cnt['bu'],cnt['im'],cnt['che'],cnt['del'],cnt['e'],cnt['la'])
          #if ((cnt['the'] < 3) == True and (cnt['de'] < 3) == True and (cnt['bu'] < 3) == True and (cnt['im'] < 3) == True and ((cnt['e'] + cnt['che'] + cnt['del'] + cnt['la'] < 5) == True)):
          #else:
          #  flag = True
          #  break
          '''
          if flag == False:
            f_error = open(output_error_file, "a")
            message = "Page " + str(img_count) + " failed to find the correct orientation.\n"
            f_error.write(message)
            f_error.close() 
          else:
          '''
          # converts images to strings
          csv_text.append(text)
          csv_id.append(str(files[pdf_index]['id'])+"_"+str(img_count))
          pdf_name.append(files[pdf_index]['name'])

        
        
        
        
        df = pd.DataFrame({'page id':csv_id, 'name': pdf_name, 'page text':csv_text})
        print("csv saved at " + output_dir+folder_name+"page.csv")
        df.to_csv(output_dir+folder_name+"page.csv")

# %% [markdown]
# ### Sets up output CSV file and calls `big_loop()`

# %%
def catalog_walk(top):    ## pass in folder link
  #snapshot_file = '/snapshot-1'
  snapshot_file = '/snapshot10'
  csvoptions = {'dialect': csv.excel}
 
  OUTFILE = open("/content/drive/My Drive/catalog_not_in_use.csv", "a")
  csvwriter = csv.writer(OUTFILE)
  maxfiles = 10
  big_loop(top, csvwriter, maxfiles)
  OUTFILE.close()

# %% [markdown]
# ### Specifies input and output directories and calls `catalog_walk()`

# %%
snapshot_file = '/snapshot-10.txt'
FOLDER = 'application/vnd.google-apps.folder'
catalog_walk(top)
# Out:
# 2021-02-28 10:03:54,758 INFO MainThread URL being requested: GET https://www.googleapis.com/drive/v3/files/1yei52gRB7vJZCD7RjlTIp0urGnmQCQ20?alt=json
# walk function is called
# 2021-02-28 10:03:55,165 INFO MainThread stack size 1
# 2021-02-28 10:03:55,166 INFO MainThread dir ['180_input']
# 2021-02-28 10:03:55,172 INFO MainThread URL being requested: GET https://www.googleapis.com/drive/v3/files?orderBy=folder%2Cname%2CcreatedTime&fields=kind%2C+nextPageToken%2C+incompleteSearch%2C+files%28id%2C+name%2C+mimeType%2C+md5Checksum%2C+webViewLink%2C+createdTime%2C+modifiedTime%2C+size%29&q=%271yei52gRB7vJZCD7RjlTIp0urGnmQCQ20%27+in+parents&alt=json
# 2021-02-28 10:03:55,492 INFO MainThread subdirs 0 files 6
# New folder is created
# image idx:  1
# image idx:  2
# image idx:  3
# image idx:  4
# image idx:  5
# Orientation to be used1
# Counter({'pue': 10, 'ay': 7, '<': 6, '03': 6, '2': 6, '¢': 6, 'Jo': 5, 'UT': 5, 'uo': 4, 'a': 4, '-': 4, '_': 3, 'Sd': 3, 'z': 3, '&': 3, 'JO': 3, '8': 3, '3nq': 3, 'y': 3, 'zo': 3, 'ayy': 3, '4': 3, 'e': 3, '=': 3, 'a8uey>': 2, 'SMNd': 2, 'UF': 2, 'amos': 2, 'aie': 2, 'g': 2, 'ay3': 2, 'aaey': 2, 'ue': 2, '7': 2, 'og': 2, '(4)': 2, '“II': 2, 'yons': 2, 'aq': 2, 'Aq': 2, 'sayz': 2, 'go': 2, 'of': 2, 'aut': 2, 'i': 2, '|': 2, '“Toa': 2, '‘+g': 2, 'adj': 2, 'aq)': 2, 'jou': 2, '°33N3': 2, '>': 2, '>)': 2, '(9923)': 1, 'aatTo': 1, 'atAgz': 1, '-ARzy': 1, 'aea': 1, 'uezo,': 1, '*qeg': 1, '—Ugn,»': 1, 'tZ': 1, 'pa8rem': 1, '*z': 1, 'eat': 1, 'Wry': 1, '38T': 1, 'usIatd': 1, '-qeH': 1, '¢)oUT33ee': 1, 'SMNG': 1, 'upquedy': 1, 'sa': 1, 'sjuBUOSUOD': 1, 'BuTMOTTOJZ': 1, 'B07': 1, '-U-': 1, 'UOTIMFUTSse': 1, 'TeTNZa1': 1, 'sy': 1, 'sang': 1, 'Atqeqoad': 1, 'osty': 1, 'Preage': 1, 'sem': 1, 'aight': 1, '®': 1, 'Tawky': 1, 'B': 1, 'TIP,': 1, 'Koq': 1, 'peTgh': 1, '*q9H': 1, '-PT®Xe': 1, '<<': 1, '-PTBMx': 1, 'Sa': 1, ':(pue': 1, '-B4': 1, 'aj0uU)': 1, 'spi0M': 1, 'soz': 1, 'TTe': 1, 'uz': 1, '-A': 1, '-m': 1, 'TeTarUT': 1, 'yo': 1, '242': 1, 'ST': 1, 'BuTZuoTag': 1, '‘tT': 1, 'M@Iqeaq': 1, 'SjUBUOSUOD': 1, 'Sq': 1, 'uCTIBAQUssaIdaz': 1, 'auL': 1, '°*@': 1, '*£1032TpeazquoD': 1, 'quezxa': 1, 'SexeTjar': 1, 'Bupaza': 1, '-iIms': 1, 'asoym': 1, '‘gs': 1, '293': 1, 'anz3': 1, 'ATTetoadsa': 1, 'st': 1, 'styy': 1, '‘sa8enguetq': 1, 'P9389338': 1, 'oy': 1, 'Uf;': 1, 'SaxaTyaq': 1, 'aT2y2': 1, 'sTseq': 1, '243': 1, 'sassan3': 1, 'A[tuo': 1, 'uaazt3': 1, 'spunos': 1, 'A0J': 1, 'pajse88ns': 1, 'uot': 1, 'e[NopI18': 1, 'uorjysod': 1, '(z)': 1, '*AT@ATT': 1, 'ssat': 1, 'S}': 1, 'STY3': 1, '‘peaqsuy': 1, 'PeZTTeIIOTS': 1, 'usasq': 1, 'ew': 1, 'uPeztTeasudreyd,,': 1, 'P8TTSqQeT': 1, 'Sptnos': 1, '(T)': 1, ':2a10N': 1, '21': 1, 'pri': 1, 'tn!': 1, 'veg': 1, 'al': 1, 'wey': 1, 'qu': 1, 'sips': 1, 'Tegend': 1, 'eis': 1, 'Ya': 1, 'X': 1, 'R=3': 1, 'b': 1, 'ABTIA': 1, 'Bu': 1, 'TeaeTeg': 1, '(3)': 1, 'TeIeTedarg': 1, 'apryter)': 1, '-§': 1, '$': 1, '3': 1, 'paztTBasudieyg': 1, '5': 1, 'u': 1, 's': 1, 'mae': 1, 'os': 1, 'aaa': 1, 'een': 1, 'w': 1, 'd': 1, 'q': 1, 'TRIP': 1, 'ta': 1, 'Pasfoauq”': 1, 'padzoy': 1, 'Padfoaug': 1, 'Pa': 1, 'oto,': 1, 'zuBNnUT': 1, 'UCD': 1, '[rs': 1, 'do3s': 1, 'OFITMeS-o01g': 1, 'waisXs': 1, 'AuBuosuoD': 1, 'paunsseE': 1, 'aL': 1, '‘vy': 1, 'qUeMeieIs': 1, 'Azeuyup{aIg': 1, ':£B0Touoyg': 1, 'o~': 1, 'AIP.': 1, 'es': 1, 'vsbeX': 1, '*F-02': 1, ',voT3enueq3B,': 1, 'ayq': 1, 'peTTeo': 1, 'uazzo': 1, 'f2eqpyu': 1, '2PqPpely': 1, 'SB': 1, 'spiom': 1, 'Xq': 1, 'pajuasaizdesz': 1, 'UOFIBTTWESsTp': 1, 'yuenbarz': 1, 'Azaa': 1, 'poyrsep': 1, '@SN': 1, 'TTEYS': 1, 'om': 1, 'ETMMIOF': 1, 'I3ENITY': 1, 'IEyIEY': 1, 'usane.>': 1, 'jrbhyh,': 1, '1h': 1, 'Ae.': 1, 'peromarg:': 1, 'anne': 1, '§': 1, 'ages': 1, 'ows': 1, 'o': 1, '(Stitt': 1, '-3F': 1, 'AB': 1, 'ER)': 1, 'Testbed': 1, 'peabaky': 1, '#908': 1, '#99F': 1, 'meq': 1, 's,tddrqttyg': 1, 'uSABT,,': 1, '“ST@MOA': 1, 'BY2': 1, 'ZOTARY': 1, '~9q': 1, '942': 1, 'Worz': 1, 'pariezuy': 1, 'Kem': 1, 'Qeym': 1, '203': 1, '3da0xe': 1, 'mazqaq-oj01g': 1, '20': 1, '“SMNd': 1, '‘Sd': 1, 'ssaz3s': 1, 'anoqe': 1, '8utyjou': 1, 'aouy': 1, 'am': 1, 'aouts': 1, '*ae[No2T2': 1, 'samo.': 1, '-2q': 1, 'Sutuoseaz': 1, '*zaaamoy': 1, '*3utod': 1, 'sty3': 1, "3V'S3[Nse2": 1, 'Jua8zaaqTp': 1, '9Y3': 1, '20F': 1, 'Junod.e': 1, 'Ae': 1, 'ssazjs': 1, 'OF': 1, 'seousresstp': 1, 'ey.': 1, '3ut3sa88ns': 1, '*K039TpeAqUOD': 1, 'are': 1, 'SMIOJ': 1, 'TeqiaA': 1, 'TeuyMou': 1, 'Buturanc’': 1, 'saqtnz': 1, '2eY2': 1, 'Uses': 1, '9q': 1, 'TITA': 1, 'az': 1, '“+mz03': 1, 'W103': 1, '‘maaqay': 1, 'ut': 1, 'stamoa': 1, 'e2UaTIND90': 1, 'aYy3': 1, 'pazoAap': 1, 'TTTA': 1, 'UoTssNosTp': 1, '1ajeT': 1, 'ano': 1, 'yony': 1, '(g)e': 1, 'Ny': 1, 'afety': 1, 'Tx': 1, 'atte': 1, 'Py': 1, 'paonpay': 1, '3204s': 1, 'peusy33uey': 1, '?a01qaq': 1, 'uoTR': 1, '~-Bluaseidaz': 1, 'sape18': 1, '9e247': 1, 'YOR': 1, 'aaeYy': 1, 'sTamoa': 1 ...
# 754
# 163
# Counter({'the': 28, 'of': 16, 'and': 15, '>': 14, 'a': 13, 'in': 12, 'The': 9, 'to': 8, 'type': 8, 'is': 7, 'for': 5, 'PS': 5, 'but': 4, 'are': 4, 'on': 4, 'PNWS': 4, 'vowels': 4, 'be': 4, 'by': 4, '|': 4, 'Semitic': 4, 'stative': 4, '%': 3, ':': 3, '3': 3, ',': 3, 'this': 3, 'may': 3, 'have': 3, 'Hebrew': 3, 'Heb.': 3, 'that': 3, 'forms': 3, 'der': 3, 'Grammatik': 3, '-': 3, 'not': 3, 'verbs': 3, 'common': 3, '(inherit)': 3, '(be': 3, 'A.': 2, 'B.': 2, 'sounds': 2, 'Voiced': 2, 'b': 2, '5': 2, '8': 2, '~': 2, '‘': 2, 'h': 2, '.': 2, 'attested': 2, '1.': 2, '2.': 2, 'change': 2, 'words': 2, 'yare’': 2, 'following': 2, '2': 2, 'let': 2, 'I': 2, 'original': 2, 'three': 2, 'short': 2, 'a.': 2, 'Hebrew:': 2, 'b.': 2, 'will': 2, 'stress': 2, 'be-': 2, 'we': 2, 'such': 2, 'aa': 2, 'semitischen': 2, 'Sprachen.': 2, 'Berlin,': 2, 'Bergstrdsser,': 2, 'G.,': 2, 'Reprinted.': 2, 'eee': 2, 'See': 2, '(a,i)': 2, 'iqiaS': 2, '(sit)': 2, 'yada‘': 2, '(know)': 2, 'variant': 2, 'I-N': 2, '(bear)': 2, 'gutt.': 2, 'like': 2, 'assumed': 1, 'consonant': 1, 'system': 1, 'Proto-Semitic': 1, 'Note:': 1, '(1)': 1, 'labelled': 1, '“pharyngealized"': 1, 'Stop': 1, 'Nasu': 1, 'Continuant': 1, 'Unvoiced': 1, '_Unvoiced': 1, 'Bilabial': 1, 'P': 1, 'm': 1, '(w)': 1, '°': 1, 'Interdenta': 1, 'n': 1, 'i': 1, 'Pharyngealizéd': 1, 't': 1, '4': 1, 'Ss': 1, '(phate': 1, 'Prepalatal': 1, '(y)': 1, '(8)': 1, 'Palatal': 1, 'g': 1, 'k': 1, '"9': 1, 'Velar': 1, '¢,': 1, 'z=': 1, 'xh': 1, 'Mriei': 1, '?': 1, 'ular': 1, 'Biz': 1, 'Pharyngeal': 1, '--': 1, '(dase': 1, 'ij': 1, 'tiateeh)': 1, 'corgune)': 1, 'Glottal”': 1, 'ou': 1, 'pike': 1, 'Liquid': 1, 'Le”': 1, 'instead,': 1, 'less': 1, 'likely.': 1, 'been': 1, 'glottalized': 1, '(2)': 1, 'position': 1, 'articulation': 1, 'suggested': 1, 'given': 1, 'only': 1, 'guesses': 1, 'basis': 1, 'their': 1, 'refiexes': 1, 'languages.': 1, 'This': 1, 'especially': 1, 'true': 1, '9': 1, '§': 1, 'viving': 1, 'reflexes': 1, 'some': 1, 'extent': 1, 'contradictory.': 1, 'representation': 1, 'consonants': 1, 'Belonging': 1, 'initial': 1, 'w-': 1, 'y-': 1, '(note': 1, 'wa-': 1, 'and):': 1, '*wald-': 1, '*yald-': 1, 'yéled': 1, '*wari’a': 1, '*yari’a': 1, 'Also': 1, 'probably': 1, 'regular': 1, 'assimfation': 1, 'consonant:': 1, 'S,': 1, 'whose': 1, 'sur-': 1, 'all': 1, 'few': 1, 'boy': 1, 'he': 1, 'was': 1, 'afraid': 1, '-n-': 1, '*yantin': 1, '‘*yattin': 1, 'yittén': 1, 'him': 1, 'give': 1, 'z': 1, 'merged': 1, 'z:': 1, "*'uSn-": 1, '’Szen': 1, 'ear': 1, '_.': 1, '*zayt-': 1, 'zayit': 1, 'olive(tree)': 1, 'Short:': 1, 'iu;': 1, 'long:': 1, 'u;': 1, 'diphthongs:': 1, 'aw,': 1, 'ay': 1, 'long': 1, 'an': 1, 'uncomplicated': 1, 'development:': 1, '*3': 1, '5/6': 1, '*8alas-': 1, '5416E': 1, '=': 1, '*I': 1, '*’asIr-': 1, "'astr": 1, 'prisoner': 1, '*yaSibi': 1, 'yasiba': 1, 'them': 1, 'return': 1, '3.': 1, 'development': 1, 'complicated': 1, 'inconsistent.': 1, 'For': 1, 'present,': 1, 'should': 1, 'noted:': 1, 'each': 1, 'grades': 1, 'representa-': 1, 'tion': 1, 'Lengthened': 1, 'Short': 1, 'Reduced': 1, 'ta': 1, 'a,i,e': 1, 'RL': 1, 'é': 1, 'i,a,e': 1, 'au': 1, 'uo': 1, 'a(d)': 1, 'Much': 1, 'our': 1, 'later': 1, 'discussion': 1, 'devoted': 1, 'occurrence': 1, 'these': 1, 'Hebrew,': 1, 'form': 1, 'form.': 1, 'It': 1, 'seen': 1, 'Tules': 1, 'governing': 1, 'nominal': 1, 'verbal': 1, 'contradictory,': 1, 'Suggesting': 1, 'differences': 1, 'account': 1, 'divergent': 1, 'results.': 1, 'At': 1, 'point,': 1, 'however,': 1, 'reasoning': 1, 'comes': 1, 'circular,': 1, 'since': 1, 'know': 1, 'nothing': 1, 'about': 1, 'PS,': 1, 'PNWS,': 1, 'or': 1, 'Proto-Hebrew': 1, 'except': 1, 'what': 1, 'inferred': 1, 'from': 1, 'havior': 1, 'vowels.': 1, '4.': 1, 'Some': 1, '"laws"': 1, "Philippi's": 1, 'Law:': 1, 'icc#': 1, 'acc#': 1, 'Berth~Ginsberg—baw:-ya—>yi—_in': 1, 'verb': 1, 'forms-of-the': 1, 'de': 1, 'pad': 1, 'gts': 1, 'dy—in_NWS)': 1, 'fore': 1, 'x': 1, 'Po': 1, 'Qrermine': 1, 'trerecete.': 1, 'Kytal': 1, 'e-otmti~': 1, 'c.': 1, 'katkat': 1, 'kitk ...
# 605
# 390
# Counter({'the': 28, 'of': 17, '>': 15, 'and': 14, 'in': 13, 'The': 10, 'a': 10, 'to': 8, 'is': 7, 'type': 7, 'PS': 6, 'on': 5, '-': 5, 'Semitic': 5, '3': 4, 'but': 4, 'for': 4, 'are': 4, 'Hebrew': 4, 'PNWS': 4, 'vowels': 4, 'be': 4, 'by': 4, 'stative': 4, 'common': 4, '%': 3, 'h': 3, 'may': 3, 'have': 3, 'this': 3, 'Heb.': 3, '7': 3, 'that': 3, '2': 3, 'not': 3, 'verbs': 3, '(inherit)': 3, '(be': 3, 'II.': 2, 'A': 2, 'A.': 2, 'system': 2, 'Voiced': 2, ',': 2, '8': 2, 't': 2, 'z': 2, 'ee': 2, 'sounds': 2, 'attested': 2, 'B.': 2, '1.': 2, 'change': 2, 'words': 2, 'following': 2, 'let': 2, '2.': 2, 'C.': 2, 'development': 2, 'original': 2, 'an': 2, 'For': 2, 'three': 2, 'G': 2, 'short': 2, 'Hebrew:': 2, 'ta': 2, 'will': 2, 'stress': 2, 'we': 2, 'such': 2, 'C.,': 2, 'Linguistics.': 2, 'Esp.': 2, 'der': 2, 'Grammatik': 2, 'semitischen': 2, 'Sprachen.': 2, 'Berlin,': 2, 'Bergstrdsser,': 2, 'G.,': 2, 'Reprinted.': 2, 'Hebrfische': 2, 'Akkadian:': 2, 'ibas': 2, '(<': 2, '<': 2, 'forms': 2, 'iqiaS': 2, 'yada‘': 2, '(sit)': 2, '(know)': 2, 'variant': 2, 'I-N': 2, '(bear)': 2, 'gutt.': 2, 'like': 2, 'Phonology:': 1, 'Preliminary': 1, 'Statement': 1, 'assumed': 1, 'consonant': 1, 'Proto-Semitic': 1, 'Stop': 1, 'Nasu': 1, 'Continuant': 1, '=a': 1, 'Unvoiced': 1, '_Unvoiced': 1, 'J': 1, 'Bilabial': 1, 'b': 1, 'P': 1, 'm': 1, '(wy': 1, 'Interdenta}': 1, 'EEE)': 1, 'Son': 1, '?': 1, 'd': 1, 'n': 1, 's': 1, 'Plivgngesiivea': 1, '$s': 1, '(phate': 1, 'Prepalatal': 1, '(y)': 1, '5': 1, '(8)': 1, 'Palatal': 1, 'g': 1, 'k': 1, '"9': 1, 'Velar': 1, '|': 1, 'Lar': 1, '.': 1, 'Ceatpatlatal': 1, 'q': 1, 'By': 1, 'x=': 1, 'hb': 1, 'Phatyngeal': 1, '£': 1, 'ie': 1, 'out': 1, '(hae': 1, ')': 1, 'Glottai®': 1, 'oa': 1, 'Pk': 1, 'r': 1, 'e': 1, 'Liguid': 1, 'ue': 1, 'Note:': 1, '(1)': 1, 'labelled': 1, '“pharyngealized"': 1, 'been': 1, 'glottalized': 1, 'instead,': 1, 'less': 1, 'likely.': 1, '(2)': 1, 'position': 1, 'articulation': 1, 'suggested': 1, 'given': 1, 'only': 1, 'guesses': 1, 'basis': 1, 'their': 1, 'refiexes': 1, 'languages.': 1, 'This': 1, 'especially': 1, 'true': 1, '9': 1, '&,': 1, 'whose': 1, 'sur-': 1, 'viving': 1, 'reflexes': 1, 'some': 1, 'extent': 1, 'contradictory.': 1, 'representation': 1, 'consonants': 1, 'Belonging': 1, 'initial': 1, 'w-': 1, 'y-': 1, 'all': 1, 'few': 1, '(note': 1, 'wa-': 1, 'and):': 1, '*wald-': 1, '*yald-': 1, 'yéled': 1, 'boy': 1, 'ewari’a': 1, '*yari’a': 1, 'yaré’': 1, 'he': 1, 'was': 1, 'afraid': 1, 'Also': 1, 'probably': 1, 'regular': 1, 'assimiation': 1, '-n-': 1, 'consonant:': 1, '*yantin': 1, '‘*yattin': 1, 'yittén': 1, 'him': 1, 'give': 1, 'merged': 1, 'z:': 1, '*°uSn-': 1, '’Szen': 1, 'ear': 1, '_': 1, '*zayt-': 1, 'z4yit': 1, 'olive(tree)': 1, 'NEL': 1, '192': 1, 'vowel': 1, 'its': 1, 'Shor': 1, 't:': 1, 'adiu;': 1, 'long:': 1, 'aI': 1, 'a;': 1, 'diphthongs:': 1, 'aw,': 1, 'ay': 1, 'long': 1, 'uncomplicated': 1, 'development:': 1, '3.': 1, '*B': 1, '5/6': 1, '*8alG0-': 1, '34163': 1, '*I': 1, '*’asIr-': 1, "'astr": 1, 'prisoner': 1, 'wD': 1, '*yaSibi': 1, 'yasiba': 1, 'them': 1, 'return': 1, 'complicated': 1, 'inconsistent,': 1, 'present,': 1, 'should': 1, 'noted:': 1, 'each': 1, 'grades': 1, 'representa-': 1, 'tion': 1, 'Lengthened': 1, 'Short': 1, 'Reduced': 1, 'a,i,e': 1, 'RL': 1, 'é': 1, 'i,a,e': 1, 'ey': 1, '6': 1, 'u,0': 1, 'a(d)': 1, 'Much': 1, 'our': 1, 'later': 1, 'discussion': 1, 'devoted': 1, 'occurrence': 1, 'these': 1, 'Hebrew,': 1, 'form': 1, 'form.': 1, 'It': 1, 'seen': 1, 'Tules': 1, 'governing': 1, 'nominal': 1, 'verbal': 1, 'forms.': 1, 'contradictory,': 1, 'Suggesting': 1, 'differences': 1, 'account': 1, 'divergent': 1, 'results.': 1, 'At': 1, 'point,': 1, 'however,': 1, 'reasoning': 1, 'be-': 1, 'comes': 1, 'circular,': 1, 'since': 1, 'know': 1, 'nothing': 1, 'about': 1, 'PS,': 1, 'PNWS,': 1, 'or': 1, 'Proto-Hebrew': 1, 'except': 1, 'what': 1, 'inferred': 1, 'from': 1, 'be-~': 1, 'havior': 1, 'vowels.': 1, '"laws"': 1, "Philippi's": 1, 'Law:': 1, 'icc#': 1, 'acc#': 1, 'read': 1, 'ee ...
# 578
# 393
# Counter({'pue': 10, '<': 7, 'ay': 7, 'Jo': 6, 'ayy': 6, '¢': 5, '03': 4, '&': 4, 'jo': 4, 'aie': 4, '3': 4, 'a': 4, '=': 3, '_': 3, 'z': 3, '8': 3, '3nq': 3, 'UF': 3, 'uo': 3, '-': 3, '>': 3, 'UT': 3, 'e': 3, 'ay}': 3, 'Sd': 2, '38T': 2, 'ay3': 2, 'sz': 2, 'SMNd': 2, 'ST': 2, '203': 2, 'zo': 2, 'spunos': 2, '|': 2, 'an': 2, 'yons': 2, 'aq': 2, 'Aq': 2, 'sayz': 2, '2': 2, 'ke': 2, 'DUS': 2, '‘-y': 2, '‘ueyoerds': 2, 'Tap': 2, 'aq)': 2, 'jou': 2, 'sqiaa': 2, 'N-I': 2, 'al': 2, '(9823)eafTO': 1, 'aThEz': 1, '-24ezy': 1, 'zea': 1, 'uezo,': 1, '*qeR': 1, '-UQN,»': 1, "'Z": 1, 'pa8iem': 1, '*z': 1, 'eats': 1, 'Wry': 1, 'usIatdé': 1, '-qeaH': 1, '¢)UT33eAe': 1, 'SMG': 1, 'upquedy': 1, 'sa': 1, 'sjuUBUOSUOD': 1, 'BuTMOTTOZ': 1, 'B02': 1, '-U-': 1, 'UOTIAFUTSse': 1, 'zBTNBa1': 1, 'aSuey>': 1, 'sung': 1, 'e&': 1, 'Atqeqoad': 1, 'osty': 1, 'Preaze': 1, 'sem': 1, ',arBh': 1, 'eB,': 1, 'Trek,': 1, 'Bb,': 1, 'TIehy': 1, 'Koq': 1, 'paTgh': 1, '*q9H': 1, '=<': 1, '-PT®he': 1, '<<': 1, '-PTBMx': 1, 'Sa': 1, ':(pue': 1, '-BM': 1, 'aj0uU)': 1, 'spi0oM': 1, 'soy': 1, 'TTe': 1, 'uF': 1, '-A': 1, '-m': 1, 'TeTATUT': 1, 'yo': 1, 'a8uey>': 1, 'e432': 1, '02': 1, 'BuTZuoTag': 1, '‘tT': 1, 'M@IqaH': 1, 'SJuBUOSUOD': 1, 'Sq': 1, 'uOTIBAUssaIdaz': 1, 'auL': 1, '*@': 1, '*£1032TperzquoD': 1, 'quezxa': 1, 'amos': 1, 'SexeTjar': 1, 'Bupapa': 1, '-ins': 1, 'asoym': 1, '‘g': 1, 'g': 1, 'y': 1, 'eniq': 1, 'ATTetToadsa': 1, 'styy': 1, '*sa8ensuet': 1, 'P9389338': 1, 'ou': 1, 'Uf;': 1, 'SaxaTyar': 1, 'aT2y2': 1, 'sTsRq': 1, '243': 1, 'sassan3': 1, '‘tuo': 1, 'uaazt3': 1, '103': 1, 'pajse88ns': 1, 'uot': 1, 'we[NopI1e': 1, 'uorazzsod': 1, '(z)': 1, '*ATaATT': 1, 'ssat': 1, 'S}': 1, 'STY3': 1, '‘peaqsuy': 1, 'PeZTTEIIOTS': 1, 'usaq': 1, 'aaey': 1, 'ew': 1, 'uPeZTTeasukzeyd,,': 1, 'pattaqet': 1, 'eUL': 1, '(T)': 1, '.:a30N': 1, 'oa': 1, '2t': 1, '__pirbs': 1, 'len': 1, 'ne': 1, 'gfOeaetD': 1, 'Bm': 1, 'pe': 1, 'Ya': 1, 'Xx': 1, 'R=3': 1, 'b': 1, '7': 1, '1PTaA': 1, 'Bu': 1, '4': 1, 'Teaeqeg': 1, '(3)': 1, '(4)': 1, 'Te3eTederg': 1, 'apryter)': 1, '—§': 1, 'é': 1, '%': 1, 'paztTeasutieyg': 1, 's': 1, 'uo4': 1, 'P': 1, 'ea': 1, 'Cone': 1, 'as': 1, '@)': 1, 'wid': 1, 'q': 1, 'TEFQPT': 1, 'Ta': 1, 'Palfoauq': 1, 'padqtoa': 1, 'pactoaun': 1, 'Pato,': 1, 'quBnutjuo)': 1, '[rs': 1, 'dojs': 1, 'OFIFMeS—-O01g': 1, 'waisXs': 1, 'juBeuosuoD': 1, 'paunssE': 1, 'aL': 1, 'cy': 1, '*F-02': 1, '®': 1, ',voTZenueq3#,': 1, 'ayq': 1, 'peTTeo': 1, 'uazjzo': 1, 'f2zeqpru': 1, 'TPqPpeMy': 1, 'SB': 1, 'spiom': 1, 'Xq': 1, 'pajuasaidesz': 1, 'UOFIPTTWTSsTp': 1, 'yuenbarz': 1, 'kiaa': 1, 'way': 1, 'PUFAREEP': 1, 'oF': 1, 'esn': 1, 'TTeys': 1, 'am': 1, 'e[nm10;': 1, ':3eNITy': 1, '€': 1, 'WyIWwy': 1, 'OD': 1, 'Mnpe0': 1, 'pr}': 1, 'Ve': 1, '"pra': 1, 'Ae:': 1, '~CSiint': 1, 'SFA': 1, 'peal': 1, 'ee)': 1, '_teqbes': 1, 'pegbek,': 1, 'Rpemusp': 1, 'ees': 1, 'yates': 1, 'omrsdl': 1, '#908': 1, '#OOE': 1, 'tet': 1, 's,tddyqttyq': 1, '-e': 1, 'uSABT,,': 1, 'euwos': 1, 'a)': 1, '“ST@MOA': 1, 'BY2': 1, 'JO': 1, 'ZOTARY': 1, '~9q': 1, '942': 1, 'Worz': 1, 'pariazuz': 1, 'Kem': 1, 'Qeym': 1, '3dvoxe': 1, 'mazqaq-oj01g': 1, '20': 1, '“SMNd': 1, '‘Sd': 1, 'ssazqs': 1, '3noge': 1, 'Zutyjou': 1, 'mouy': 1, 'eouts': 1, 'fzeqnNo212': 1, 'samoo': 1, '-2q': 1, 'Sutuoseaz': 1, '*zaaamoy': 1, '*3utod': 1, 'sty3': 1, "3V'S3[Nse2": 1, '3ua8zaaqTp': 1, '9Y3': 1, '20Z': 1, 'JunoDoe': 1, 'Ae': 1, 'ssazjs': 1, 'seoustessTp': 1, '3ey2': 1, 'Bup3se88ns': 1, '*K1OIOTpezaquos': 1, 'SMIOJ': 1, 'TeqiaA': 1, 'TeuzMou': 1, 'Buturaac’': 1, 'saq—nz': 1, '2eY2': 1, 'uses': 1, '9q': 1, 'IITA': 1, 'aT': 1, '“+mz03': 1, 'W103': 1, '‘maaqay': 1, 'ut': 1, 'sqtamoa': 1, 's2UaTINII0': 1, 'aYy3': 1, 'pazoAap': 1, 'TTTA': 1, 'UOFSSNISTp': 1, 'aleT': 1, 'ano': 1, 'yony': 1, '+q': 1, '(aje': 1, 'ofn': 1, 'Ny': 1, 'afety': 1, 'Fx': 1, 'a‘tte': 1, 'Py': 1, 'paonpay': 1, '3204S': 1, 'peusy33ue7': 1, '?A91qaq': 1, 'uoTR': 1, '~Bluaseidaz': 1, 'sapei8': 1, '9e142': 1, 'YoRe': 1, 'aaeYy': 1, 'sTamoa': 1, '3A0ys': 1, 'TeuTstio': 1, 'ce': 1, "' ...
# 717
# 163
# image idx:  1
# Page
# image idx:  2
# Page
# image idx:  3
# Page
# image idx:  4
# Page
# csv saved at /content/drive/My Drive/AWCA/Colab_notebooks/OCR/OCR_PDF2Page/180_output/1nWWQVnTb-P5p-aT6nY01YpajdP0FOVX1/page.csv
# New folder is created
# image idx:  1
# image idx:  2
# image idx:  3
# image idx:  4
# image idx:  5
# Orientation to be used0
# Counter({'pue': 49, 'Jo': 44, 'ayy': 22, 'Aq': 21, 'JO': 17, 'ay)': 15, 'st': 14, '94)': 14, 'yo': 13, '0}': 12, '07': 12, '943': 11, '&': 10, 'oy)': 10, 'a': 9, 'sey': 9, '|': 8, '“dd': 8, 'e': 7, '24)': 7, '94}': 7, 'ay}': 7, 'y': 6, 'pur': 6, 'oy': 6, 'Ue': 6, 'ur': 6, 'B': 6, 'i': 6, '2': 5, '-': 5, ':': 5, 'ee': 5, 'yey': 5, ',': 5, 'ye': 5, 'oy}': 5, 'se': 5, 'yey)': 5, 'oq': 5, 'ut': 5, 'are': 4, '*': 4, 'aq': 4, 'ay': 4, 'Joy': 4, 'yey}': 4, 'om': 4, 'A': 3, '8': 3, '“4': 3, 'os': 3, '04': 3, '24}': 3, 'jo': 3, 'yy': 3, 'wow': 3, 'YIM': 3, 'uo': 3, 'UF': 3, 'UO': 3, 'ey)': 3, '03': 3, 'ore': 3, 'UI': 3, 'g': 3, 'wo': 3, 'uy': 3, 'you': 3, 'UT': 3, 'Woy': 3, 'sem': 3, 'FHL': 2, 'sap': 2, 'uozing': 2, '6961': 2, '©': 2, 'nz': 2, 'ue': 2, 'Jap': 2, '“y': 2, 'ot': 2, 'ce': 2, 'Te': 2, '.': 2, '29': 2, 'eo': 2, '“2': 2, '9p': 2, '‘': 2, 'or': 2, '=': 2, 'J0': 2, 'ug': 2, 'sry': 2, '908': 2, '243': 2, '“d': 2, 'ey}': 2, 'pod': 2, 'Uy': 2, 'ones)': 2, 'nq': 2, 'woemyoq': 2, '3': 2, 'ey': 2, '398': 2, 'porsayy': 2, '91': 2, '942': 2, 'Ul': 2, 's1y': 2, 'useq': 2, '—': 2, 'Uo': 2, 'sy': 2, 'poured': 2, 'Aeur': 2, '¢': 2, 'sour': 2, 'ae': 2, 'I': 2, 'at': 2, '+': 2, 'ou': 2, 'ayy,': 2, '9y}': 2, 'pun': 2, 'eq': 2, '64': 2, 've': 2, 'Ose': 2, 'seq': 2, '®': 2, 'St': 2, 'Ut': 2, 'mo': 2, 'Aue': 2, 'WI': 2, 'omy': 2, 'yseq': 2, 'pey': 2, 'yoory': 2, '9y)': 2, 'pu': 2, 'aida': 2, 'HAVIN': 1, '‘OA0Id': 1, '@LISYIAING': 1, 'ON.)': 1, '-(': 1, 'WYHOIG': 1, 'AUVadUIT': 1, 'vOEl': 1, '“IN-S8epI9A,': 1, '‘JOVI': 1, 'Joxpsag': 1, 'vozing': 1, ':8unqjissapy': 1, '“uareyaqioa': 1, 'aipay': 1, 'airy': 1, '‘uANT': 1, '-Uatpsrynany': 1, 'sulaJoassunyaiziq': 1, '3e[s0A,': 1, 'Jauatpirynany': 1, 'Pan': 1, 'Jaefoaay': 1, 'Jaspiag': 1, '2g': 1, '3e[19A': 1, '‘Ist': 1, 'ABnja8teq': 1, 'o1Jog': 1, 'uUaM': 1, '‘Inu': 1, '18jojza': 1, 'Bunpuasspny': 1, '‘uatpaidsaq': 1, 'duroxasuotsuazay': 1, 'aVepsojasueun': 1, '‘veupiydsea': 1, 'uptu': 1, 'puts': 1, 'saqa8snesapy': 1, 'a1]': 1, '“Usplom': 1, 'usuTUOUsJeqgn': 1, 'TYEMa': 1, 'auTay': 1, 'uury': 1, 'ardiaysnuey': 1, 'aipursagura': 1, 'aBuepseaun': 1, 'ing': 1, '‘uspuas': 1, 'Joqa3snesapy': 1, 'dap': 1, 'ueulS': 1, 'puis': 1, 'aidiysnury': 1, 'opurliapain': 1, '‘usduiry': 1, '‘¢': 1, 'iwensieseag': 1, 'Seuloyy,': 1, '“IOoW': 1, 'ep': 1, '">': 1, '“[': 1, '€%': 1, 'Ax[duiog': 1, '“ssa': 1, '/saisuny': 1, 'py': 1, 'IEMUSIaAIUG)': 1, 'JeuTUag': 1, 'Solpsyequauoiy': 1, '‘Z1a107]': 1, '‘O-Ipiaiq': 1, '“Wy': 1, 'qS¢': 1, '‘“Tasspseuisig': 1, '‘sIs0PT/spaqiaa~Z': 1, 'OC': 1, 'ly': 1, '‘yousa8iog': 1, 'Jaqessnesapy': 1, 'uaiputpsuy': 1, 'TOW)': 1, 'BP': 1, '“Fy': 1, 'saut': 1, 'xf': 1, 'ZI2I0°F': 1, 'PI': 1, 'mont': 1, 'md': 1, 'nascar': 1, "GET'S": 1, '“aategette': 1, 'ihe': 1, 'uAn[A-UayoaTyNaN]': 1, 'surasaasSunyarz1y': 1, 'Se[aA': 1, 'JouayoiTyNaNy': 1, 'eS': 1, 'JovpaAay]': 1, 'Jaxpsag': 1, '3ep19A,': 1, 'T': 1, 'pueg': 1, 'S': 1, 'fe': 1, 'Boca': 1, '8Rne': 1, 'OO': 1, 'HDs': 1, 'Pres': 1, 'IAiCT': 1, 'PALER': 1, 'joqsadingy': 1, 'UoA': 1, 'UaqadagsneIoFy': 1, 'Rg': 1, '“athy': 1, 'unsepe': 1, 'J': 1, 'ust': 1, 'sea': 1, '“qty': 1, 'piogpeag': 1, 'Ti': 1, 'gSPa': 1, 'iad': 1, '“een': 1, 'P': 1, 'ipnqiyel': 1, 'sapeuoneusaquy': 1, 's': 1, '1°3': 1, 'bIb!': 1, 'NAONNHOSUOSSLIVVON': 1, '‘40°': 1, '‘BOTFOT': 1, '“4d': 1, '“B961)': 1, 'gg': 1, 'AraI009': 1, 'jeNOUC': 1, 'UeOHOMY': 1, 'out': 1, 'Feumof': 1, '‘useqooel': 1, '+7': 1, '5,': 1, '“BST': 1, '“(Q96T)': 1, '98': 1, 'sorpnag': 1, 'oruoqoyy': 1, '[eumof': 1, '‘noureg': 1, '‘(°y': 1, ',,': 1, 'nin': 1, 'Eek': 1, '1d': 1, '(8961),88': 1, 'A210': 1, 'pequaLIG': 1, '"Sy': 1, 'App': 1, 'apy': 1, 'Of': 1, 'Peep': 1, 'of': 1, 'SoporrT': 1, '“a': 1, '“Ite': 1, 'uorenby,': 1, 'ai)': 1, 'Ho': 1, '‘pup': 1, '(86:4,': 1, 'do:': 1, 'joqduey': 1, 'one': 1, 'MPR': 1, '“BSL': 1, 'oSb6‘e@': 1, 'pup': 1, 'ee-ogedd': 1, '‘ecg': 1, 'ueple]': 1, 'umyuswrEsey': 1, 'snia4': 1, '‘1ddns': 1, '‘rag': 1, '-onrrelin': 1, 'PUY': 1, 'METS': 1, '“edeg': 1, '“HW': 1, 's-': 1, '“oN': 1,  ...
# 1640
# 713
# Counter({'the': 142, 'of': 76, 'and': 62, 'in': 32, 'to': 31, 'a': 26, 'that': 25, 'is': 23, 'by': 19, 'between': 12, 'Greek': 11, 'with': 11, 'are': 10, 'from': 10, 'as': 9, 'on': 8, 'pp.': 8, 'an': 7, 'The': 7, 'for': 7, 'which': 7, 'it': 7, 'Ugaritic': 7, 'Mycenaean': 7, 'be': 7, 'der': 6, 'Near': 6, 'Mediterranean': 6, 'at': 6, 'East': 6, 'Ugarit': 6, 'i': 5, 'first': 5, 'have': 5, 'has': 5, 'evidence': 5, 'parallels': 5, 'Homer': 5, 'texts': 5, 'Kumarbi': 4, 'cycle': 4, 'Theogony': 4, 'classical': 4, 'two': 4, 'possible': 4, 'if': 4, 'parallel': 4, 'Eastern': 4, 'poems': 4, 'been': 4, 'not': 4, 'but': 4, 'p.': 4, 'Crete': 4, 'Journal': 4, 'culture': 4, 'general': 4, 'Keret': 4, 'ff.': 4, 'will': 4, 'its': 4, 'Herausgeber': 3, 'Verlag': 3, 'Butzon': 3, '&': 3, 'Bercker': 3, 'more': 3, 'role': 3, 'this': 3, 'Song': 3, 'is,': 3, 'even': 3, 'fact': 3, 'secondly': 3, 'we': 3, 'I': 3, 'Oriental': 3, 'most': 3, 'same': 3, 'his': 3, 'power': 3, 'god': 3, 'Gordon,': 3, '1966),': 3, 'Linear': 3, 'B': 3, 'Homeric': 3, 'our': 3, 'were': 3, 'society': 3, 'scholars': 3, 'epic': 3, 'second': 3, 'when': 3, 'only': 3, 'literature': 3, 'Manuskripte': 2, 'sind': 2, 'zu': 2, '1969': 2, 'Kevelaer': 2, 'und': 2, 'es': 2, 'so': 2, '1': 2, 'monster': 2, 'link': 2, 'single': 2, 'text,': 2, 'sympathy': 2, 'opinion': 2, 'Hesiod': 2, 'set': 2, 'elements': 2, 'convincing': 2, 'provided': 2, 'But': 2, 'idea': 2, 'would': 2, 'originally': 2, 'could': 2, 'spread': 2, 'Ullikummi': 2, 'latter': 2, 'however,': 2, 'offering': 2, 'side': 2, 'being': 2, 'weapon': 2, 'A': 2, 'before': 2, 'separate': 2, 'offered': 2, 'equivalent': 2, 'whose': 2, 'See': 2, 'Evidence': 2, 'Minoan': 2, '(Ventnor,': 2, 'NJ.,': 2, 'Studies': 2, '(1968),': 2, 'see': 2, '(Gottingen,': 2, 'suggests': 2, 'To': 2, 'also': 2, 'and,': 2, 'had': 2, 'established': 2, 'drawn': 2, 'written': 2, 'earliest': 2, 'decipherment': 2, 'tablets': 2, 'later': 2, 'us': 2, 'sketch': 2, 'social': 2, 'Gordon’s': 2, 'developed': 2, 'literature,': 2, 'Bible': 2, 'may': 2, 'content': 2, 'they': 2, 'any': 2, 'much': 2, 'after': 2, 'reactions': 2, 'scholar': 2, 'particularly': 2, 'made': 2, 'koine': 2, 'character': 2, 'Iliad': 2, '-': 2, 'part': 2, 'millennium': 2, '(London,': 2, 'Bible’': 2, 'study': 2, 'Greece,': 2, 'time': 2, 'problems': 2, 'realization': 2, 'common': 2, 'was': 2, 'By': 2, 'en-Palastin': 1, 'aSiue': 1, 'ANSE': 1, 'aid': 1, 'Loretz': 1, '~': 1, 'Anschriften': 1, 'K.': 1, 'Bergerhof,': 1, '4130': 1, 'Meerbeck/Moers,': 1, 'Bismarckstr.': 1, '35b': 1, 'M.': 1, 'Dietrich-O.': 1, 'Loretz,': 1, 'Altorientalisches': 1, 'Seminar': 1, 'Universitat,': 1, '44': 1, 'Miinster/Westf.,': 1, 'Domplatz': 1, '23': 1, 'J.': 1, 'C.': 1, 'de': 1, 'Moor,': 1, 'Thomas': 1, 'Seerattstraat': 1, '5,': 1, 'Kampen,': 1, 'Niederlande': 1, 'einen': 1, 'senden.': 1, 'Fiir': 1, 'unverlangt': 1, 'eingesandte': 1, 'kann': 1, 'keine': 1, 'Gewahr': 1, 'iibernommen': 1, 'werden.': 1, 'Die': 1, 'nicht': 1, 'verpflichtet,': 1, 'unangeforderte': 1, 'Rezensionsexemplare': 1, 'besprechen.': 1, 'Riicksendung': 1, 'erfolgt': 1, 'nur,': 1, 'wenn': 1, 'Porto': 1, 'beigefiigt': 1, 'ist.': 1, '©': 1, 'Neukirchener': 1, 'des': 1, 'Erzichungsvereins': 1, 'Neukirchen-Vluyn.': 1, 'Alle': 1, 'Rechte': 1, 'vorbehalten.': 1, 'Herstellung:': 1, 'Kevelaer.': 1, 'Internationales': 1, 'Jahrbuch': 1, 'Bradford': 1, 'e': 1, '“fobr.': 1, 'Perr': 1, ';': 1, 'Herausgegeben': 1, 'von': 1, 'Kurt': 1, 'Bergerhof:-': 1, 'Manfried': 1, 'Dietrie': 1, 'We': 1, 'dffdecer’s,': 1, 'shay': 1, 'Aap»': 1, '#': 1, 'ge': 1, 'ven': 1, 'nie': 1, 'Bucks': 1, '-Cyode': 1, 'Moor': 1, 'ui.': 1, 'dergersor': 1, '“athe': 1, 'ad': 1, 'Band': 1, 'eee': 1, 'NAT...)': 1, 'Lr.': 1, 'I.': 1, 'CODY': 1, '‘': 1, 'oo': 1, 'EEE': 1, 'ESAS!': 1, 'SIS': 1, 'AIEE,': 1, 'NAVE': 1, 'West': 1, 'Semites': 1, 'Play': 1, 'creative': 1, 'evolution': 1, 'than': 1, 'mere': 1, 'receivers': 1, "transmitters.'7": 1, 'Hesiod’s': 1, 'relevant': 1, 'report': 1, 'several': 1, 'reasons:': 1, 'setting': 1, ' ...
# 1017
# 1570
# Counter({'the': 135, 'of': 71, 'and': 60, 'to': 33, 'in': 27, 'a': 25, 'that': 25, 'is': 20, 'by': 20, 'with': 13, 'between': 12, 'pp.': 11, 'on': 10, 'as': 10, 'Greek': 10, 'at': 9, 'be': 9, 'are': 9, 'an': 8, 'from': 8, 'Ugaritic': 8, 'Mycenaean': 8, 'have': 7, 'it': 7, 'Ugarit': 7, 'der': 6, 'his': 6, 'has': 6, 'Near': 6, 'Mediterranean': 6, 'for': 6, 'Homer': 6, 'been': 5, 'not': 5, 'first': 5, 'p.': 5, 'The': 5, 'which': 5, 'ff.': 5, 'evidence': 5, 'parallels': 5, 'East': 5, 'texts': 5, 'Verlag': 4, '—': 4, ';': 4, 'Linear': 4, 'we': 4, 'if': 4, 'parallel': 4, 'Theogony': 4, 'Eastern': 4, 'Oriental': 4, 'but': 4, '1966),': 4, 'Crete': 4, 'also': 4, 'was': 4, 'culture': 4, 'B': 4, 'general': 4, 'Keret': 4, '(London,': 4, 'literature': 4, 'will': 4, 'its': 4, 'Herausgeber': 3, 'Butzon': 3, '&': 3, 'Bercker': 3, 'des': 3, 'i': 3, 'Hesiod': 3, 'may': 3, 'A': 3, 'tablets': 3, 'this': 3, 'would': 3, 'most': 3, 'same': 3, 'latter': 3, 'being': 3, 'Gordon,': 3, 'Journal': 3, '(1968),': 3, 'see': 3, 'had': 3, 'Homeric': 3, 'poems': 3, 'our': 3, 'were': 3, 'society': 3, 'classical': 3, 'scholars': 3, 'Gordon’s': 3, 'epic': 3, 'second': 3, 'two': 3, 'when': 3, 'Mycenae': 3, 'only': 3, '-': 2, ':': 2, 'Manuskripte': 2, 'sind': 2, 'zu': 2, '1969': 2, 'Kevelaer': 2, 'und': 2, 'Neukirchener': 2, 'THE': 2, 'e': 2, '1': 2, 'Kumarbi': 2, 'myth': 2, 'Song': 2, 'Gordon': 2, 'now': 2, 'attention': 2, 'material,': 2, 'some': 2, 'claim': 2, 'what': 2, 'already': 2, 'published': 2, 'subject': 2, 'Astour,': 2, 'who': 2, 'role': 2, 'single': 2, 'text,': 2, 'sympathy': 2, 'opinion': 2, 'set': 2, 'elements': 2, 'convincing': 2, 'provided': 2, 'But': 2, 'is,': 2, 'could': 2, 'spread': 2, 'both': 2, 'however,': 2, 'offering': 2, 'Hesiod,': 2, 'years': 2, 'side': 2, 'god': 2, 'equivalent': 2, 'whose': 2, 'See': 2, 'Evidence': 2, 'Minoan': 2, '(Ventnor,': 2, 'Studies': 2, '(Gottingen,': 2, 'suggests': 2, 'possible': 2, 'To': 2, 'Society': 2, '88': 2, 'P.': 2, 'Walcot': 2, 'brought': 2, 'Ras': 2, 'Shamra': 2, 'so': 2, 'established': 2, 'drawn': 2, 'written': 2, 'earliest': 2, 'decipherment': 2, 'later': 2, 'us': 2, 'sketch': 2, 'social': 2, 'developed': 2, 'literature,': 2, 'Bible': 2, 'content': 2, 'whether': 2, 'or': 2, 'they': 2, 'any': 2, 'even': 2, 'after': 2, 'reactions': 2, 'scholar': 2, 'particularly': 2, 'made': 2, 'koine': 2, 'character': 2, 'In': 2, 'From': 2, '.': 2, 'Iliad': 2, 'Webster': 2, '3': 2, 'part': 2, 'millennium': 2, 'ay': 2, '26': 2, '7': 2, 'study': 2, 'Greece,': 2, 'time': 2, 'reporter': 2, 'secondly': 2, 'discoveries': 2, 'realization': 2, 'common': 2, 'Foci': 1, 'ths': 1, 'Adserpumsk': 1, 'unde:': 1, 'id': 1, 'Loretz': 1, '}': 1, 'es': 1, '-C..de': 1, 'Moor': 1, 'anal': 1, 'Pde”': 1, 'Anschriften': 1, 'K.': 1, 'Bergerhof,': 1, '4130': 1, 'Meerbeck/Moers,': 1, 'Bismarckstr.': 1, '35b': 1, 'M.': 1, 'Dietrich-O.': 1, 'Loretz,': 1, 'Altorientalisches': 1, 'Seminar': 1, 'Universitat,': 1, '44': 1, 'Miinster/Westf.,': 1, 'Domplatz': 1, '23': 1, 'J.': 1, 'C.': 1, 'de': 1, 'Moor,': 1, 'Thomas': 1, 'Seerattstraat': 1, '5,': 1, 'Kampen,': 1, 'Niederlande': 1, 'einen': 1, 'senden.': 1, 'Fir': 1, 'unverlangt': 1, 'eingesandte': 1, 'kann': 1, 'keine': 1, 'Gewahr': 1, 'iibernommen': 1, 'werden.': 1, 'Die': 1, 'nicht': 1, 'verpflichtet,': 1, 'unangeforderte': 1, 'Rezensionsexemplare': 1, 'besprechen.': 1, 'Riicksendung': 1, 'erfolgt': 1, 'nur,': 1, 'wenn': 1, 'Porto': 1, 'beigefiigt': 1, 'ist.': 1, '©': 1, 'Erzichungsvereins': 1, 'Neukirchen-Vluyn.': 1, 'Alle': 1, 'Rechte': 1, 'vorbehalten.': 1, 'Herstellung:': 1, 'Kevelaer.': 1, 'Verlags-Nr.': 1, '1394': 1, 'LIBRARY': 1, 'BRIGHAM': 1, '\\.': 1, '(NU': 1, 'UNIVERSITY': 1, 'PROVO,': 1, 'UTAH': 1, 'aq': 1, 'UGARIT-FORSCHUNGEN': 1, 'vol.': 1, '|': 1, 'rb': 1, '<': 1, 'Worcot,': 1, 'Internationales': 1, 'Jahrbuch': 1, 'f': 1, 'BG': 1, 'omens': 1, 'Bradford': 1, 'v': 1, '“fobn.': 1, 'Perr': 1, 'Herausgegeben': 1, 'von': 1, 'ffes': 1, 'C,-de': 1, 'Moor.': 1, 'berger': 1, '“ae': 1, '——': 1, 'More': ...
# 1040
# 1493
# Counter({'Jo': 54, 'pue': 46, 'ayy': 18, 'Aq': 15, 'JO': 13, 'st': 13, 'ay)': 13, '07': 12, '943': 12, 'oy)': 11, '94)': 10, 'sey': 9, '94}': 9, 'yo': 9, 'B': 9, 'se': 8, '&': 8, 'ut': 8, '“dd': 7, 'ay}': 7, 'uy': 7, 'oy}': 7, 'e': 7, 'y': 6, 'pur': 6, 'yy': 6, 'jo': 6, 'UO': 6, 'UT': 6, 'oy': 5, '03': 5, '0}': 5, 'ur': 5, 'yey)': 5, 'pure': 5, 'sy': 5, '*': 4, 'i': 4, '24)': 4, 'ay': 4, 'Ur': 4, 'you': 4, 'yey}': 4, 'om': 4, 'ore': 4, 'YIM': 4, 'uozing': 3, 'ue': 3, ':': 3, '04': 3, 'oy]': 3, '“d': 3, '|': 3, '24}': 3, '8': 3, 'pu': 3, 'aq': 3, '1': 3, '09': 3, 'ae': 3, 'UE': 3, 'Ue': 3, 'oq': 3, 'ou': 3, '2': 2, '6961': 2, '©': 2, 'nz': 2, 'Jap': 2, '29': 2, 'a': 2, 'ee': 2, 's': 2, 'ce': 2, 'OS': 2, '-': 2, ',': 2, 'pod': 2, 'seq': 2, 'eg': 2, 'woy': 2, 'uo': 2, '9y)': 2, 'ete': 2, 'Inq': 2, '3': 2, 'rey': 2, 'WHY': 2, 'sursod': 2, 'seo': 2, '4q': 2, 'iqreum': 2, 'yey': 2, 'useq': 2, '31': 2, 'aya': 2, 'UY': 2, 's1': 2, 'a4)': 2, 'Joy': 2, 'ayy,': 2, '243': 2, '¥': 2, '‘': 2, 'wo': 2, 'Ul': 2, 'OMT': 2, '01': 2, 'Ose': 2, 'yas': 2, 'ey)': 2, 'Aue': 2, 'axe': 2, 'Aeur': 2, 'Woy': 2, 'g': 2, 'pey': 2, '9y3': 2, 'yor': 2, 'Jr': 2, 'ay3': 2, 'A[puooes': 2, 'au}': 2, 'yoy': 2, '‘JavpaAry': 1, 'Jaxpiog': 1, ':8unqpoaszapy': 1, '“uaaeyaqioa': 1, 'aipay': 1, 'alty': 1, '“WANA': 1, '-UaIpIyNany': 1, 'suraseasSunyorzsq': 1, 'sap': 1, 'S¥[Jaq': 1, 'JouawpsrynaN': 1, 'Pun': 1, 'Jev[aaay': 1, 'Jaxpieg': 1, '2%': 1, '81194': 1, '‘Ist': 1, 'ABpja8teq': 1, 'o1jog': 1, 'uuaM': 1, '‘anu': 1, '1Zjojza': 1, 'Bunpuasspny': 1, '‘uatpaidsaq': 1, 'are[durexasuoisuazay': 1, 'aVepiojasueun': 1, '‘seuprydsea': 1, 'uptu': 1, 'puts': 1, 'saqa8snesazy': 1, 'Iq]': 1, '“Usplom': 1, 'usuTuoUsagn': 1, 'qTyemary)': 1, 'auTay': 1, 'uury': 1, 'aidisysnuey': 1, 'aipursagura': 1, '’uepeaaun': 1, 'inj': 1, '“uapuas': 1, 'Joqa8snesapy': 1, 'dap': 1, 'ueulS': 1, 'puis': 1, 'aidiuysnuey': 1, 'aPpurlsapaIn': 1, '‘uaduiey': 1, '‘¢': 1, 'WRIISNLIIIE': 1, 'SYUIOY],': 1, '‘JOOW': 1, 'ap': 1, '"D': 1, '“[': 1, '€%': 1, 'Ax[duog': 1, '“ssay': 1, '/saisuny': 1, 'py': 1, 'IEMUsIaAIUG': 1, 'JeurUag': 1, 'SatpsiTequatioapy': 1, '‘Z1as07]': 1, '‘C-tpiiaiq': 1, '“Ww': 1, 'qS¢': 1, '“Tasspseulsig': 1, '‘sIB0PL/spaqiae~ZW': 1, 'OC': 1, 'ly': 1, 'yousa8ieg': 1, '“y': 1, 'Jaqessnesepy': 1, 'uaiimpsuy': 1, 'Oy': 1, 'ser': 1, 'BATT': 1, 'so': 1, '—': 1, 'Se': 1, 'Be': 1, 'BEND': 1, 'eee': 1, 'Jovpaaayy': 1, 'Jaxpsag': 1, '3ep19A,': 1, 'I': 1, 'pueg': 1, 'Lareigagrag': 1, 'UoA': 1, 'UaqaSagsneIapy': 1, '2g': 1, 'ith': 1, 'puogpeag': 1, 'yonqiyet': 1, 'soeORUMST': 1, 'Sea': 1, 'ewer': 1, 'ed': 1, 'Cones)': 1, 'an': 1, 'LY': 1, 'OU}': 1, '[eumof': 1, '‘uasqooes': 1, '‘Loz': 1, '“BST': 1, '“4': 1, '“(996T)': 1, '98': 1, 'eorpmag': 1, 'ormoqoyy': 1, '[rumof': 1, '‘nourg': 1, '‘(7y': 1, ',,': 1, 'BFL': 1, '“Ad': 1, '§(8961),88': 1, 'A1m0g': 1, 'peuaLG': 1, 'he': 1, 'iy': 1, 'SERB': 1, 'OBEY': 1, 'un': 1, 'poco': 1, 'f': 1, '“SPORT': 1, '“A': 1, '‘Ta': 1, '1qreun': 1, 'uoRenbe,': 1, 'yf': 1, '‘pur': 1, 'ig.': 1, 'WP': 1, 'pda.': 1, 'Teqdure;': 1, 'ose': 1, 'aap': 1, '|,': 1, 'oH': 1, 'SL}': 1, '6': 1, 'C6': 1, 'REPBE-OBAd': 1, '‘gc6T': 1, 'upioy': 1, '<z': 1, 'umyusmiesey': 1, 'anje,': 1, '“ddns': 1, '“PRALINE': 1, 'By': 1, 'Ut': 1, 'Ig': 1, '‘odog': 1, '“HW': 1, 'sil': 1, 'N': 1, 'PATE': 1, '60,': 1, 'L/TPRR': 1, 'pre': 1, 'qq': 1, 'apy': 1, 'Tapered': 1, 'orqusod': 1, 'sysa83ns': 1, '‘enaZ': 1, 'somod': 1, 'sry': 1, 'peropueims': 1, 'AiPumM': 1, 'souory': 1, 'YoY': 1, 'Surproooe': 1, '“(T': 1, '‘02': 1, '‘s)': 1, 'snmoig': 1, 'sniopoiq': 1, 'poszssaad': 1, 'uoHIpen': 1, 'urjary': 1, '22-69': 1, '‘(g961': 1, '‘uoturn95)': 1, 'arydosopmyg': 1, 'uoyostyoord': 1, 'voyny': 1, 'mz': 1, 'uerpnyg': 1, '‘uadeag': 1, 'seyoqsupyuy': 1, '‘soyostoy': 1, '“7': 1, '298': 1, '999X)': 1, '903': 1, 'uC': 1, '‘22821': 1, '“(96': 1, '1)': 1, '27': 1, 'sorpmag': 1, 'woysey': 1, 'seaN!': 1, 'Teumof': 1, '“moisy': 1, '“OW': 1, '‘Zot': 1, '“(g96T': 1, '‘y0q': 1, '“aN': 1, '919K)': 1, 'uvoUT]': 1, 'yLreSy': 1, 'Te ...
# 1521
# 699
# image idx:  1
# Page
# image idx:  2
# Page
# image idx:  3
# Page
# image idx:  4
# Page
# csv saved at /content/drive/My Drive/AWCA/Colab_notebooks/OCR/OCR_PDF2Page/180_output/16HPqLYRUFRdCk-MKtm7xoPpi4rouWyFD/page.csv
# New folder is created
# image idx:  1
# image idx:  2
# image idx:  3
# image idx:  4
# image idx:  5
# Orientation to be used1
# Counter({'Jo': 74, 'ay}': 47, 'JO': 30, 'st': 22, 'pue': 22, '0}': 21, 'UT': 18, 'aq': 14, 'ayy': 14, '“d': 13, '&': 11, 'oy}': 11, 'oY}': 10, 'speaq': 9, 'se': 9, 'YIM': 9, '|': 9, 'Aq': 9, 'ATUO': 9, 'asn': 9, 'ur': 8, 'pur': 8, 'ay': 7, 'Ul': 7, 'PIO': 7, 'jo': 7, 'e': 7, 'fo': 7, 'sem': 7, 'sty}': 7, 'ay)': 6, 'OU': 6, 'Woy': 6, '*d': 5, 'ase': 5, 'OY}': 5, 'ey}': 5, 'JOU': 5, 'ale': 5, 'B': 5, 'auo': 5, 'yey}': 5, 'Wor': 4, 'SI': 4, 'OF': 4, 'UL': 4, 'oy': 4, 'Jey}': 4, 'PUL': 4, 'peaq': 4, 'ut': 4, 'UO': 4, '‘d': 3, '‘Id': 3, '12': 3, '1': 3, '‘J': 3, '‘sakey': 3, 'speag': 3, '18': 3, 'jou': 3, 'IBY}': 3, 'Aue': 3, '4,': 3, 'Ur': 3, 'WIJ': 3, '1e': 3, 'pasn': 3, 'Ue': 3, 'ay]': 3, 'puke': 3, 'alam': 3, 'Id': 3, '“H': 3, 'sqeseos': 3, '10J': 3, 'UMOUY': 3, 'STYI': 3, ',': 3, 'punoj': 3, 'ST': 3, 'ABW': 3, '07': 3, 'saop': 2, '“ELE': 2, '‘ade': 2, '‘poled': 2, 'P[O': 2, 'si': 2, '“OLE': 2, '-d': 2, '‘dd': 2, '=': 2, 'AY)': 2, '32': 2, 'ul': 2, '1B': 2, 'you': 2, 'SE': 2, 'Op': 2, 'Woes': 2, 'Os': 2, 'ou': 2, 'aUO': 2, 'pure': 2, 'Aay}': 2, 'Yons': 2, 'II': 2, 'YOM]': 2, 'UE': 2, 'YBNoY}': 2, 'POLag': 2, 'syisodap': 2, 'poled': 2, 'YA': 2, ']': 2, 'YoryM': 2, 'YOryM': 2, '‘speaq': 2, 'JOJ': 2, 'Uo': 2, 'yerebbes': 2, 'uo': 2, 'ye': 2, 'WOPsUTY': 2, 'ode': 2, 'Aysea': 2, 'eB': 2, 'EY)': 2, '‘yeyy': 2, 'JO}': 2, 'SEM': 2, '“Id': 2, '‘]': 2, 'Ie': 2, '‘1': 2, '‘1d': 2, '‘TI': 2, '“6S': 2, 'dd': 2, 'PUR': 2, '“OSE': 2, 'IO': 2, 'suo': 2, 'TVSV': 2, 'WV': 2, '“dd': 2, 'ayep': 2, 'Ayseudq': 2, '3}': 2, 'WOIJ': 2, 'Ad': 2, '[Te': 2, 'ABUL': 2, 'A1OISTY': 2, 'ose': 2, 's': 2, '10': 2, 'sour': 2, 'oy)': 2, '03': 2, 'Wo': 2, 'Suunp': 2, 'WOPSUTY': 2, 'PUNO}': 2, 'am': 2, 'sqeieds': 2, 'IT': 2, '‘Ayseudq': 2, '‘asn': 2, 'FHL': 2, 'NO': 2, '‘Ty': 2, 'YILM': 2, 'ey)': 2, 'WOIy': 2, 'yey)': 2, 'sI': 2, 'at': 2, 'oud': 2, '$8': 1, '79g': 1, '“pig}': 1, '‘[': 1, 'sl4jsOsag': 1, 'sB': 1, 'Aiea': 1, 'Se': 1, 'Ppalindd0': 1, 'sAeY': 1, 'PNOd': 1, 'Yyons': 1, 'eY3': 1, 'AypIqissod': 1, 'Moye': 1, 'YysNoyy': 1, '‘Ss': 1, '“oUOW': 1, 'Zod': 1, '“pigs': 1, 'sosyAH': 1, 'pus': 1, '[]': 1, 'SLjsOsag': 1, 'Zuljep': 1, 'Paqldsap': 1, 'asaymasya': 1, 'Tay': 1, 'Asoqauas': 1, 'WOOL}': 1, '[BIEN': 1, 'Sty)': 1, '“GaAIMOH': 1, '“ILA': 1, '‘Yasvsnzy': 1, 'ayeipautsayuy': 1, 'Issty': 1, 'WOPSULY': 1, '2y}': 1, 'Jaystdos': 1, 'QUID}': 1, 'paoesd': 1, 'yorym': 1, '“ISAyjowe': 1, 'awWoOs': 1, '‘speag': 1, 'AfUO': 1, 'Poute}UOD': 1, 'YoTyM': 1, 'YaseseH': 1, 'Bps': 1, '[eng': 1, 'apse!': 1, 'os[R': 1, 'pynoys': 1, 'aJoON': 1, '‘Ep': 1, '‘T': 1, 'TO': 1, '‘ep': 1, 'dO': 1, '“69€': 1, '‘oe': 1, 'gO': 1, '"89€': 1, '‘sed': 1, '1d6': 1, '“LOE': 1, '"6TT': 1, '4aidaag': 1, '"99€': 1, '(9': 1, 'MH)': 1, 'OS': 1, '“wap': 1, 'wdg': 1, 'Hat}': 1, 'Ly': 1, '“ou': 1, '"SOE': 1, '*speaq-leq': 1, 'iskyjawe': 1, '‘tp': 1, '[eting': 1, '‘09': 1, '“Wap': 1, 'utq': 1, 'Mal': 1, 'JD': 1, '“P9E': 1, '‘WAYJOWE': 1, 'JayNWE': 1, 'KUe': 1, '93290]': 1, 'a[qeUN': 1, 'We': 1, '“ABAIMOP{': 1, '“WOPZULY': 1, 'BULEP': 1, ',.JIqQay-]a': 1, 'MED': 1, 'eppaseysow': 1, '‘110-19': 1, 'Jen': 1, 'puNgy': 1, 'usaq': 1, 'saey': 1, '**': 1, '*': 1, 'UOIIsOdwoo': 1, 'pazePs': 1, 'isKyrowe': 1, '“sedsjay': 1, '‘UBI[aUsES': 1, 'apeul': 1, 'SyajnUY,,': 1, '1saqeas': 1, '“LZ': 1, '“iayamar': 1, '‘UOSUIyH': 1, 'A': 1, '“(POlad': 1, 'ateIpaussaqUy': 1, 'ISIy)': 1, 'LOT': 1, '(WOPUIy': 1, 'PIO)': 1, 'OPSE': 1, 'Seaes3': 1, '“KXT1X': 1, '‘ppaspisow': 1, '—-“E9E': 1, '*WXa]U0d': 1, 'AjseUA': 1, 'YIXIS': 1, 'Apiea': 1, 'YILY': 1, 'WO': 1, 'sjaynweE': 1, 'dnosZ': 1, '‘9': 1, '"OU': 1, '‘SEZ': 1, 'SnuLaadw': 1, '"TIE': 1, '"J': 1, '6L': 1, '“(pL6t)': 1, '09': 1, 'Var': 1, '‘audeg': 1, '“D': 1, '“f': 1, 'pajou': 1, 'spmog': 1, 'Pes': 1, 'OM}': 1, 'SjUaUIseLy': 1, 'asoyL': 1, '"LOE': 1, 'Arerodutayuoo': 1, 'ATYsnod': 1, '‘SAY': 1, 'LOUIE': 1, 'PaUle]UOO': 1, 'IYsTT': 1, 'Ist.GaUag': 1, 'qUIO]': 1, 'Alaqjomoal': 1, 'uordaTjoo': 1, 'iyi': 1, 'Ino': 1, 'syutod': 1, 'ATFs': 1, 'UOJUNIg': 1, 'aTTYM': 1, '00}': 1, 'U ...
# 1772
# 907
# Counter({'the': 129, 'of': 104, 'in': 47, 'amethyst': 45, 'and': 40, 'to': 34, 'is': 34, 'from': 29, 'that': 24, 'a': 24, 'at': 24, 'p.': 22, 'Twelfth': 20, 'this': 20, 'be': 15, 'which': 14, 'The': 14, 'are': 14, 'Dynasty': 13, 'beads': 13, 'First': 12, 'early': 11, 'Dynasty.': 11, 'were': 11, 'only': 11, 'not': 11, 'found': 11, 'Old': 10, 'with': 10, 'as': 10, 'for': 10, 'Kingdom': 9, 'by': 9, 'Intermediate': 9, 'Period': 8, 'was': 8, 'use': 8, 'one': 8, 'Amethyst': 7, 'I': 7, 'bead': 7, 'no': 7, 'contained': 7, 'it': 7, 'or': 7, 'Sesostris': 7, 'scarabs': 7, 'some': 6, 'appear': 6, 'burials': 6, 'burial': 6, 'amulets': 6, 'evidence': 6, 'there': 6, 'objects': 6, 'prior': 6, 'tomb': 6, 'This': 5, 'Brunton': 5, 'on': 5, 'dating': 5, 'dated': 5, 'necklace': 5, 'other': 5, 'any': 5, 'date': 5, 'reign': 5, 'made': 5, 'may': 5, 'history': 4, 'Egyptian': 4, 'deposits': 4, 'all': 4, 'have': 4, 'There': 4, 'noted': 4, 'though': 4, 'more': 4, 'Eleventh': 4, 'before': 4, 'its': 4, 'they': 4, 'pl.': 4, 'pp.': 4, 'Hayes,': 4, 'Scepter': 4, 'during': 4, 'While': 4, 'example,': 4, 'A.': 4, 'I,': 4, 'graves': 3, 'would': 3, 'Protodynastic': 3, 'such': 3, 'many': 3, 'an': 3, 'However,': 3, 'extensive': 3, 'material': 3, 'Saqqarah': 3, 'apparently': 3, 'been': 3, 'scarab': 3, 'used': 3, 'seem': 3, 'grave': 3, 'am': 3, 'small': 3, 'while': 3, 'ball-beads': 3, 'jewellery': 3, 'amethyst,': 3, 'Matmar,': 3, 'should': 3, 'most': 3, 'It': 3, 'known': 3, 'does': 3, 'following': 3, 'Dynasty,': 3, 'Middle': 3, 'Wadi': 3, 'inscriptions': 3, 'time': 3, 'see': 3, 'H.': 3, 'SCARAB': 3, 'Lahun': 3, 'For': 3, 'has': 2, 'almost': 2, 'archaeological': 2, 'age': 2, 'Intermed-': 2, 'iate': 2, 'Egypt': 2, 'stones': 2, 'amethyst.': 2, 'period': 2, 'can': 2, 'investigation': 2, 'number': 2, 'Giza': 2, 'recorded': 2, 'Nag’': 2, 'beads.': 2, 'site': 2, 'basis': 2, 'string': 2, 'summary': 2, 'precise': 2, 'question': 2, 'do': 2, 'general': 2, 'Brunton’s': 2, 'Queen': 2, 'includes': 2, 'about': 2, 'pendant': 2, 'Qau,': 2, '1025': 2, 'late': 2, 'clear': 2, 'xiith': 2, 'discovered': 2, 'Qau': 2, 'included': 2, 'date.': 2, 'Grave': 2, 'both': 2, 'group': 2, 'Period,': 2, 'consist': 2, 'pendant.': 2, 'contemporary': 2, 'later': 2, 're-date': 2, 'But': 2, 'light': 2, 'points': 2, 'rich': 2, 'Senebtisi': 2, 'Lisht': 2, 'fragments': 2, 'two': 2, 'JEA': 2, 'f.': 2, 'Mostagedda,': 2, '1': 2, 'Teti': 2, 'Pyr.': 2, 'Cem.': 2, '1,': 2, 'QB': 2, 'QB,': 2, '43.': 2, '370.': 2, 'beads,': 2, 'cemetery': 2, 'described': 2, 'II': 2, '2.': 2, 'THE': 2, 'DYNASTY': 2, 'use,': 2, 'absence': 2, 'pre-Twelfth': 2, 'but': 2, 'we': 2, 'Lucas': 2, 'miles': 2, 'Abu': 2, 'source': 2, 'statement': 2, 'few': 2, 'indicate': 2, 'expeditions': 2, 'thus': 2, 'I.': 2, '354': 2, 'earlier': 2, 'quarries': 2, 'time.': 2, 'notes': 2, 'description': 2, 'Deir': 2, 'usually': 2, 'per': 2, 'those': 2, 'Il,': 2, 'Materials,': 2, 'ASAE': 2, '33': 2, 'Fakhry,': 2, 'Inscriptions': 2, 'single': 2, 'Winlock,': 2, 'quite': 2, 'available': 2, 'royal': 2, 'belonging': 2, 'Amenemes': 2, 'must': 2, 'than': 2, 'finds': 2, 'Tomb': 2, '(scarab);': 2, 'LTD,': 2, 'long': 1, 'plundering': 1, 'easily': 1, 'accessible': 1, 'destroyed': 1, '‘evidence.': 1, 'entirely': 1, 'absent': 1, 'between': 1, 'surprising': 1, 'since': 1, 'throughout': 1, 'contact': 1, 'areas': 1, 'hard': 1, 'imported.': 1, 'Such': 1, 'startling': 1, 'gap': 1, 'centuries,': 1, 'verified': 1, 'complete': 1, 'period.': 1, 'undertaken.': 1, 'substantial': 1, 'sites,': 1, 'located': 1, '362': 1, 'another': 1, 'Inter-': 1, 'mediate': 1, 'Mostagedda.': 1, '363': 1, 'seems': 1, 'cemeteries': 1, 'sites': 1, 'ed-Dér': 1, '(with': 1, 'exception': 1, 'just': 1, 'noted)': 1, 'spite': 1, 'ample': 1, 'quantities': 1, 'earliest': 1, '364': 1, 'One': 1, 'doubtful': 1, 'example': 1, 'latter': 1, 'indirectly': 1, 'who,': 1, 'fine': 1, 'amulets,': 1, 'dates': 1, '6': 1, '(Firth': 1, 'excavations)': 1, 'Period.': 1, 'silver': 1, 'wire.': 1, '365': 1, 'Due': 1, 'method': 1, 'publi ...
# 902
# 1706
# Counter({'the': 140, 'of': 113, 'in': 51, 'amethyst': 49, 'and': 47, 'is': 37, 'to': 34, 'that': 31, 'a': 29, 'from': 29, 'p.': 26, 'at': 25, 'this': 21, 'Twelfth': 20, 'which': 16, 'be': 16, 'are': 15, 'The': 14, 'beads': 14, 'early': 13, 'Dynasty': 13, 'with': 12, 'only': 12, 'First': 12, 'as': 12, 'for': 11, 'Dynasty.': 11, 'were': 11, 'not': 11, 'found': 11, 'use': 10, 'by': 10, 'Old': 10, 'Sesostris': 10, 'was': 9, 'burials': 9, 'contained': 9, 'Kingdom': 9, 'Intermediate': 9, 'I,': 9, 'it': 8, 'Period': 8, 'I': 8, 'one': 8, 'pl.': 8, 'other': 7, 'objects': 7, 'evidence': 7, 'Amethyst': 7, 'bead': 7, 'no': 7, 'burial': 7, 'there': 7, 'or': 7, 'scarabs': 7, 'This': 6, 'may': 6, 'have': 6, 'some': 6, 'appear': 6, 'on': 6, 'amulets': 6, 'prior': 6, 'tomb': 6, 'pp.': 6, 'A.': 6, 'than': 5, 'more': 5, 'Brunton': 5, 'dating': 5, 'though': 5, 'dated': 5, 'necklace': 5, 'any': 5, 'date': 5, 'reign': 5, 'made': 5, 'Matmar,': 5, 'material': 4, 'used': 4, 'beads.': 4, 'most': 4, 'small': 4, 'history': 4, 'Egyptian': 4, 'deposits': 4, 'such': 4, 'all': 4, 'There': 4, 'noted': 4, 'Eleventh': 4, 'before': 4, 'its': 4, 'they': 4, 'f.': 4, 'Hayes,': 4, 'Scepter': 4, 'does': 4, 'during': 4, 'While': 4, 'example,': 4, 'Lahun': 4, 'indicate': 3, 'we': 3, 'can': 3, 'single': 3, 'Egypt': 3, 'graves': 3, 'would': 3, 'Protodynastic': 3, 'many': 3, 'an': 3, 'However,': 3, 'extensive': 3, 'Saqqarah': 3, 'apparently': 3, 'been': 3, 'scarab': 3, 'seem': 3, 'grave': 3, 'am': 3, 'while': 3, 'ball-beads': 3, 'jewellery': 3, 'amethyst,': 3, 'Cem,': 3, 'QB': 3, 'should': 3, 'It': 3, 'known': 3, 'following': 3, 'Dynasty,': 3, 'Middle': 3, 'Abu': 3, 'Wadi': 3, 'inscriptions': 3, 'time': 3, 'see': 3, 'H.': 3, 'Il,': 3, 'SCARAB': 3, 'For': 3, 'evident': 2, 'so': 2, 'limited': 2, 'times': 2, 'that,': 2, 'Such': 2, 'stone': 2, 'has': 2, 'almost': 2, 'archaeological': 2, 'age': 2, 'Intermed-': 2, 'iate': 2, 'stones': 2, 'amethyst.': 2, 'period': 2, 'investigation': 2, 'number': 2, 'Giza': 2, 'recorded': 2, 'Nag’': 2, 'site': 2, 'basis': 2, 'string': 2, 'summary': 2, 'precise': 2, 'question': 2, 'do': 2, 'general': 2, 'Brunton’s': 2, 'Queen': 2, 'includes': 2, 'about': 2, 'pendant': 2, 'Qau,': 2, '1025': 2, 'late': 2, 'clear': 2, 'xiith': 2, 'discovered': 2, 'Qau': 2, 'included': 2, 'date.': 2, 'Grave': 2, 'both': 2, 'group': 2, 'Period,': 2, 'consist': 2, 'pendant.': 2, 'contemporary': 2, 'later': 2, 'he': 2, 're-date': 2, 'But': 2, 'light': 2, 'points': 2, 'rich': 2, 'Senebtisi': 2, 'Lisht': 2, 'fragments': 2, 'two': 2, 'JEA': 2, 'Mostagedda,': 2, 'Teti': 2, 'Pyr.': 2, '1,': 2, '43.': 2, '370.': 2, 'also': 2, 'beads,': 2, 'cemetery': 2, 'described': 2, 'II': 2, '2.': 2, '56.': 2, 'APPENDIX': 2, 'THE': 2, 'DYNASTY': 2, 'use,': 2, 'absence': 2, 'pre-Twelfth': 2, 'but': 2, 'Lucas': 2, 'miles': 2, 'source': 2, 'statement': 2, '35?': 2, 'few': 2, 'expeditions': 2, 'thus': 2, 'I.': 2, 'earlier': 2, 'quarries': 2, 'time.': 2, 'notes': 2, 'description': 2, 'Deir': 2, 'el-Meleq': 2, 'usually': 2, 'per': 2, 'those': 2, 'Materials,': 2, 'ASAE': 2, '33': 2, 'Fakhry,': 2, 'von': 2, 'Winlock,': 2, 'Tarkhan': 2, 'Ward': 2, 'ON': 2, '(reign': 2, 'engraved': 2, 'name': 2, 'quite': 2, 'available': 2, 'royal': 2, 'belonging': 2, 'Amenemes': 2, 'must': 2, 'finds': 2, 'Tomb': 2, '(scarab);': 2, 'LTD,': 2, 'mace-head': 1, 'rarely': 1, 'artifacts': 1, '361': 1, 'these': 1, 'hardly': 1, 'think': 1, 'terms': 1, 'chance': 1, 'bits': 1, 'pieces': 1, 'filtered': 1, 'into': 1, 'Nile': 1, 'Valley': 1, 'through': 1, 'trade.': 1, 'perhaps': 1, 'south.': 1, 'That': 1, 'bead,': 1, 'tiny': 1, 'minority': 1, 'even': 1, 'amply': 1, 'justifies': 1, 'view': 1, 'reached': 1, 'sporadically': 1, 'minute': 1, 'quantities.': 1, 'generalization': 1, 'must,': 1, 'course,': 1, 'qualified': 1, 'obvious': 1, 'facts': 1, 'rare': 1, 'seen': 1, 'actual': 1, 'implies,': 1, 'long': 1, 'plundering': 1, 'easily': 1, 'accessible': 1, 'destroyed': 1, '‘evidence.': 1, 'entirely': 1, 'absent': 1, 'between': 1, 'surpri ...
# 1026
# 1866
# ...
# 1793
# 636
# Counter({'the': 103, 'of': 72, 'a': 32, 'is': 30, 'to': 29, 'that': 28, 'in': 27, 'and': 20, 'not': 16, 'for': 15, 'as': 14, 'be': 14, 'The': 13, 'by': 12, 'on': 10, 'was': 10, 'der': 9, 'with': 9, 'Aleppo': 9, 'it': 8, 'Alalah': 8, 'at': 7, 'or': 7, 'an': 7, '*': 7, 'one': 7, 'there': 7, 'are': 7, 'very': 7, 'A': 6, 'this': 6, 'years': 6, 'between': 6, 'time': 6, 'two': 6, 'no': 5, 'if': 5, 'date': 5, 'which': 5, 'generations': 5, 'his': 5, 'long': 5, 'their': 5, 'from': 4, 'Near': 4, 'New': 4, 'SIMA': 4, 'fact': 4, 'It': 4, 'should': 4, 'only': 4, 'but': 4, 'later': 4, 'than': 4, 'under': 4, 'given': 4, 'we': 4, 'further': 4, 'argument': 4, 'may': 4, 'too': 4, 'average': 4, 'generation': 4, 'last': 4, 'Eastern': 3, 'British': 3, 'Paris': 3, 'und': 3, 'Chronology': 3, 'Berlin.': 3, '2001,': 3, 'level': 3, 'might': 3, 'so': 3, 'masiktu': 3, 'need': 3, 'second': 3, 'has': 3, 'both': 3, 'historical': 3, 'possible': 3, 'Idrimi': 3, 'point': 3, '“': 3, 'king': 3, 'mentioned': 3, 'into': 3, 'that.': 3, 'much': 3, 'must': 3, 'number': 3, 'years,': 3, 'just': 3, 'line': 3, 'chronology': 3, 'SCIEM': 2, '2000': 2, 'im': 2, 'Akademie': 2, 'Wi': 2, 'Millennium': 2, 'Austrian': 2, 'data': 2, 'Annales': 2, 'de': 2, '1987,': 2, 'W': 2, 'Gent.': 2, 'time.': 2, 'Colloquium': 2, 'Ancient': 2, 'since': 2, '1996:': 2, '(ed.)': 2, '1995.': 2, 'et': 2, 'York.': 2, 'al.': 2, 'Gothenburg.': 2, 'Journal': 2, 'Studies,': 2, 'Deutschen': 2, 'History': 2, 'Berlin,': 2, 'Archaeology': 2, 'Mediterranean': 2, 'den': 2, 'third': 2, 'van': 2, 'beginning': 2, 'basis': 2, 'end': 2, 'wares': 2, 'does': 2, 'other': 2, 'terms,': 2, 'death': 2, 'been': 2, 'Hittite': 2, 'attack': 2, 'MAYER': 2, 'our': 2, 'Talmi-Sarruma': 2, 'destruction': 2, 'he': 2, 'such': 2, 'after': 2, '—': 2, 'place': 2, 'probable': 2, 'political': 2, 'being': 2, 'ity': 2, 'give': 2, 'generally': 2, 'Idrimi’s': 2, '1998,': 2, 'role': 2, 'played': 2, 'then': 2, 'con-': 2, 'treaty': 2, 'Mittani': 2, 'Tudhaliya': 2, 'However,': 2, 'evidence': 2, 'Another': 2, 'still': 2, 'can': 2, 'holds': 2, 'Barattarna': 2, 'This': 2, 'exactly': 2, 'Cf': 2, 'appears': 2, 'ion': 2, 'make': 2, 'because': 2, 'statistics': 2, 'first': 2, 'older': 2, 'cases': 2, 'events': 2, 'middle': 2, 'parallel': 2, 'dynasty': 2, 'kings': 2, 'reigned': 2, 'rulers': 2, 'Franz': 2, 'If': 2, 'respective': 2, 'ES': 2, 'obviously': 2, 'brother': 2, 'Jarimlim': 2, 'who': 2, 'Ammitaqum,': 2, 'He': 2, 'Alalah,': 2, 'based': 2, 'used': 2, 'Spezialforschungsbereich': 1, 'Syuchronisiernng': 1, 'Hochkulturen': 1, 'éstlichen': 1, 'Mittelineerraum': 1, '2.': 1, 'Jahrtausend': 1, 'v.': 1, 'Ch': 1, 'Osterreichischen': 1, 'schatten': 1, 'beim': 1, 'Fonds': 1, 'zur': 1, 'Fé': 1, 'derung': 1, 'wissenschattlichen': 1, 'Forsch': 1, 'ng': 1, 'Dit': 1, 'Research': 1, 'Programme': 1, '“The': 1, 'Synchronisation': 1, 'Civiligations': 1, 'Medite': 1, 'Second': 1, 'B.C.~': 1, 'Academy': 1, 'Sciences': 1, 'Science': 1, 'Fund': 1, 'nean': 1, 'sh': 1, 'Library': 1, 'Cataloguing': 1, 'Py': 1, 'ation': 1, 'Catalogue': 1, 'ord': 1, 'book': 1, 'available': 1, 'Libra': 1, 'y.': 1, 'Umsehlagbild:': 1, 'Dominique': 1, 'Colon,': 1, 'Igar-Lim,': 1, 'Editions': 1, 'Reche': 1, 'MARI.': 1, 'Recherches': 1, 'Interdis': 1, 'vilisations,': 1, 'Abbildung': 1, 'auf': 1, 'Seite': 1, '148.': 1, 'plinaires': 1, '5.': 1, 'Die': 1, 'verwendete': 1, 'Papiersorte': 1, 'ist': 1, 'aus': 1, 'chlortrei': 1, 'gebleichtem': 1, 'Zellstoff': 1, 'hergestellt,': 1, 'frei': 1, 'von': 1, 'séurebildenden': 1, 'Bestandt:': 1, 'len': 1, 'alterungsbestandi,': 1, 'Alle': 1, 'Rechte': 1, 'vorbehalten': 1, 'ISBN': 1, '3-7001-3278-6': 1, 'Copyright': 1, '©': 1, '2004': 1, 'chische': 1, 'Oster': 1, 'nschatten,': 1, 'aegaedan,': 1, 'Akkadica': 1, 'slegaeunt,': 1, 'Liége,': 1, 'Akkadica,': 1, 'eAkkadica': 1, 'VY9-120': 1, 'Just': 1, 'Proc': 1, '«lings': 1, 'Luter-': 1, 'aLnst': 1, 'AOAT': 1, 'BAR.IS': 1, 'BASOR': 1, 'BBVO': 1, 'CivANE': 1, 'CivPrOr': 1, 'DaM': 1, 'Hd': 1, 'AML': 1, 'national': 1, 'ou': 1, ...
# 1094
# 1254
# Counter({'the': 115, 'of': 88, 'a': 39, 'to': 35, 'in': 31, 'is': 31, 'that': 30, 'and': 24, 'The': 17, 'for': 17, 'as': 17, 'not': 16, 'be': 15, 'by': 14, 'on': 13, 'Aleppo': 11, 'was': 11, 'der': 10, 'an': 10, 'with': 10, '*': 9, 'years': 9, 'time': 9, 'this': 8, 'Alalah': 8, 'there': 8, 'it': 8, 'are': 8, 'at': 7, 'or': 7, 'one': 7, 'between': 7, 'long': 7, 'two': 7, 'very': 7, 'no': 6, 'if': 6, 'date': 6, 'later': 6, 'than': 6, 'which': 6, 'generations': 6, 'their': 6, 'A': 5, 'from': 5, 'Near': 5, 'under': 5, 'given': 5, 'we': 5, 'average': 5, 'his': 5, 'kings': 5, 'British': 4, 'History': 4, 'Chronology': 4, 'New': 4, 'Berlin.': 4, 'attack': 4, 'fact': 4, 'level': 4, 'should': 4, 'only': 4, 'but': 4, 'has': 4, 'further': 4, 'Idrimi': 4, 'argument': 4, 'may': 4, 'too': 4, 'must': 4, 'number': 4, 'years,': 4, 'generation': 4, 'chronology': 4, 'last': 4, 'DER': 4, 'Civilisations': 3, 'Eastern': 3, 'Mediterranean': 3, 'Millennium': 3, 'Paris': 3, 'und': 3, 'Studies,': 3, 'et': 3, 'SIMA': 3, '2001,': 3, 'would': 3, 'been': 3, 'place': 3, 'It': 3, 'does': 3, 'other': 3, 'might': 3, 'so': 3, 'masiktu': 3, 'need': 3, 'second': 3, 'Hittite': 3, 'both': 3, 'historical': 3, 'destruction': 3, 'possible': 3, 'Idrimi’s': 3, 'point': 3, 'Of': 3, '1998,': 3, 'king': 3, 'mentioned': 3, 'more': 3, 'still': 3, 'first': 3, 'into': 3, 'that.': 3, 'much': 3, 'line': 3, 'middle': 3, 'dynasty': 3, 'about': 3, 'von': 2, 'Hermann': 2, 'SCIEM': 2, '2000': 2, 'Die': 2, 'im': 2, 'chen': 2, 'Akademie': 2, 'zur': 2, '“The': 2, 'Austrian': 2, 'data': 2, 'i': 2, 'de': 2, '1987,': 2, '©': 2, '2004': 2, 'Ultrashort': 2, 'Akkadica': 2, 'Gent.': 2, 'Ancient': 2, '2000.': 2, 'since': 2, 'Minster.': 2, 'Haven.': 2, '(ed.)': 2, '1995.': 2, 'York.': 2, 'Mainz.': 2, 'al.': 2, '(1987);': 2, 'Gothenburg.': 2, 'OxfEncANE': 2, 'Journal': 2, 'Deutschen': 2, 'Archaeology': 2, 'East.': 2, 'Archdologie,': 2, 'den': 2, 'Emar': 2, 'have': 2, 'third': 2, 'beginning': 2, 'basis': 2, 'end': 2, 'wares': 2, 'terms,': 2, 'were': 2, 'death': 2, 'fall': 2, 'Babylon': 2, 'together': 2, 'out': 2, 'our': 2, 'year': 2, 'introduction': 2, 'Tudbaliya.': 2, 'he': 2, 'such': 2, 'after': 2, '~': 2, 'probable': 2, 'political': 2, 'being': 2, 'period': 2, 'ity': 2, 'give': 2, 'generally': 2, 'Mayer': 2, '1992.': 2, '1': 2, '“': 2, 'KLENGEL': 2, 'matter': 2, 'scholars': 2, 'crucial': 2, '(Idr.': 2, 'role': 2, 'played': 2, 'then': 2, 'treaty': 2, 'Mittani': 2, 'Tudhaliya': 2, 'However,': 2, '|.': 2, 'evidence': 2, 'Another': 2, 'In': 2, 'case': 2, 'holds': 2, 'Barattarna': 2, 'This': 2, 'whether': 2, 'can': 2, 'exactly': 2, 'Cf.': 2, 'Mursili': 2, 'appears': 2, 'Cf': 2, 'make': 2, 'because': 2, 'just': 2, 'older': 2, 'use': 2, 'cases': 2, 'events': 2, 'I': 2, 'recently': 2, 'NAGEL': 2, 'parallel': 2, 'reigned': 2, 'during': 2, 'rulers': 2, 'Franz': 2, 'If': 2, 'respective': 2, 'four': 2, 'ing': 2, 'discussion': 2, 'obviously': 2, 'brother': 2, 'Jarimlim': 2, 'who': 2, 'Alalab': 2, 'Ammitaqum,': 2, 'He': 2, 'Alalab,': 2, 'based': 2, 'used': 2, 'AKADEMIE': 2, 'Vorgelegt': 1, 'w.': 1, 'M.': 1, 'HUNGER': 1, 'Sitming': 1, 'am': 1, '8.': 1, 'Oktober': 1, '2003': 1, 'Spezialforschungsbereich': 1, 'Synuchronisiernny': 1, 'Hochkulturen': 1, '¢': 1, '2.': 1, 'dahrtausend': 1, 'v.': 1, '(': 1, 'Wissenschatten': 1, 'bein': 1, 'Fonds': 1, 'Foérderung': 1, 'wissenschaftlichen': 1, 'Forschung': 1, 'Mittelmeerraum': 1, 'Osterreic': 1, 'Special': 1, 'Research': 1, 'Programme': 1, 'Synchronisation': 1, 'Second': 1, 'B.C.”': 1, 'Academy': 1, 'Sciences': 1, 'Science': 1, 'Fund': 1, 'Library': 1, 'Catalogning': 1, 'Publication': 1, 'Catalogue': 1, 'record': 1, 'book': 1, 'iy': 1, 'available': 1, 'Libra': 1, 'ry.': 1, 'Unisehlaghild:': 1, 'Dominique': 1, 'Collon,': 1, 'r-Lim,': 1, 'Editions': 1, 'Recherche': 1, 'sur': 1, 'les': 1, 'Civili': 1, 'n:': 1, 'MARI.': 1, 'Annales': 1, 'Recherches': 1, 'Interdisciplinaires': 1, '5.': 1, 'tions,': 1, 'Abbildung': 1, 'auf': 1, 'Seite': 1, '148.': 1, 'verwendcete': 1, 'Papie ...
# 1190
# 1449
# Counter({'ayy': 43, 'Jo': 25, 'jo': 22, 'JO': 14, '04': 13, 'st': 10, 'fo': 10, 'se': 10, 'you': 9, 'SI': 9, 'ur': 8, 'yy': 8, 'UO': 8, 'pue': 8, 'aq': 8, 'Aq': 7, 'ul': 6, 'e': 6, 'OF': 6, '&': 6, 'v': 6, 'y': 5, 'oy': 5, 'UT': 5, '4': 5, 'sem': 5, 'ue': 5, 'oq': 5, 'pure': 5, 'yeyy': 5, '07': 5, 'are': 5, 'ye': 4, 'ay': 4, 'oddary': 4, '®': 4, 'OU': 4, 'auo': 4, 'pun': 3, 'A': 3, 'au': 3, 'sap': 3, '*': 3, '1': 3, 'ay)': 3, 'F': 3, 'a': 3, 'oy,': 3, 'sv': 3, 'Ay': 3, 'oy}': 3, '004': 3, 'ayep': 3, 'St': 3, 'pur': 3, '.': 3, '&q': 3, 'og': 3, 'sey': 3, 'omy': 3, 'ap': 2, '¥': 2, 'S': 2, 'Ul': 2, 'Waly': 2, 'wap': 2, 'Ue': 2, 'sp': 2, 'pen': 2, 'MON': 2, 'aye': 2, 'any': 2, 'AV': 2, 'AY': 2, 'TT': 2, 'so': 2, '19': 2, '-': 2, 'FE': 2, 'pe': 2, 'ua': 2, 'SIY': 2, 'ay}': 2, 'styy': 2, 'a1]': 2, 'uo': 2, 'jou': 2, 'puosas': 2, 'toy': 2, 'Fey}': 2, '10': 2, 'B': 2, 'Yor': 2, 'yey': 2, 'aL': 2, '9': 2, ',,': 2, 'yey}': 2, 'ep': 2, 've': 2, 'arayy': 2, 'yeuy': 2, '—': 2, 'yo': 2, 'SB': 2, 'ev': 2, 'NVA': 2, 'siseq': 2, 'AT': 2, '«': 2, 'ouy': 2, 'SE': 2, 'Buoy': 2, 'JOU': 2, 'pasn': 2, 'OWL': 2, 'sry': 2, 'sty': 2, 'oy]': 2, 'OM': 2, 'ey}': 2, 'ee': 2, 'yyy': 2, '944': 2, 'ysnl': 2, '40': 2, 'UolAy': 1, '“Uaype': 1, 'MA': 1, 'dop': 1, 'allopeyy': 1, 'oe': 1, '38]': 1, 'Yple,': 1, 'Sq': 1, 'FO0%': 1, 'G': 1, 'WWBLIAde,': 1, 'O-RLER': 1, 'LOOL-E': 1, 'NAST': 1, 'Uo': 1, 'PEYyoqsoa': 1, 'OUI': 1, 'oe)': 1, 'IpuRIseqsFuagTR': 1, 'uopagpuUeyseg': 1, 'Uapuspyqa.imes': 1, 'uoA': 1, 'Tad': 1, '‘HP': 1, 'wasioy': 1, 'jyoysyaz': 1, 'uray': 1, '1993': 1, 'W4p1OTLD': 1, 'sue': 1, '4st': 1, 'ayios,': 1, 'ced': 1, 'aopuaaaiaa': 1, '{Tp': 1, '“SFT': 1, 'O}AG': 1, 'poe': 1, 'Sunpyaqqy': 1, '‘zRGE': 1, 'slau': 1, '‘suc': 1, 'TpAsyy': 1, 'salyorsyoay': 1, 'sopeMy': 1, '“TYP': 1, ']Y': 1, 'cur': 1, 'AL!)': 1, 'Sey': 1, 'IT': 1, 'Plaqooyy': 1, 'nipal': 1, 'Wy': 1, 'reg]': 1, '‘dopfog': 1, 'enbmnerocy': 1, ':ppiqeepyosurg': 1, 'ATRIQUT': 1, 'STIG,': 1, 'WoL': 1, 'apRTENR': 1, 'yoo': 1, 'sry}': 1, 'pLosaa': 1, 'andopesy,y': 1, 'RCP': 1, 'UOTy': 1, 'lang': 1, 'surasopeye)': 1, 'Aamagry': 1, 'ysranig.': 1, 'puny': 1, 'oouslog': 1, 'ueLysny': 1, 'Aapwoy': 1, 'uPLIySMY': 1, '1)': 1, 'ef': 1, 'UNUTATTTA,': 1, 'PNOVag': 1, 'Pa!': 1, 'W4oyseM': 1, 'SUIQRSTAIY': 1, 'UOLpestuOAYyoUd': 1, '0006': 1, 'WHEDS': 1, 'ewMe': 1, 'Boag': 1, 'y1wasey': 1, 'pewody': 1, 'eau.': 1, 'WL.': 1, 'SUNIPSloy,': 1, 'UATPIPYRPsuassLA': 1, '«ap': 1, 'SUMIAPAGT': 1, 'aNZ': 1, 'spuoyp': 1, 'ulpaq': 1, 'HOUFEYASUOSSTAA': 1, 'Lap': 1, 'OLMTOPRY': 1, 'GaYOSIpAIALd9}SQ)': 1, 'dap': 1, 'Ys)': 1, 'plasnyqayep': 1, 'Zz': 1, 'uaangny': 1, 'qaogy': 1, 'aap': 1, 'Funaaisrw': 1, '000': 1, 'WATOS': 1, 'Wosoqssunyosaoyemads': 1, 'TUN': 1, 'BLOW': 1, 'pay': 1, 'A,': 1, 'qoudg': 1, 'arp': 1, '“Ulplog,': 1, '“yfoyasypasay-juareg': 1, 'voyoxnagy': 1, 'uabun': 1, 'dquafforas': 1, 'FYI': 1, 'YIsSVASE': 1, '“OISUBYE': 1, '“96H,': 1, 'AUIS': 1, 'saepaaay': 1, '/UAN]': 1, 'A-Moqo.cryna': 1, 'uaBunyossog': 1, 'panb,7': 1, 'TIMOR': 1, 'oMopoeyony': 1, 'uaTostyemsurpaca': 1, 'pau': 1, 'amopoudssy': 1, 'nz': 1, 'ussunyons.aqu': 1, '“UapeRq': 1, '“SOLAL': 1, '‘uare': 1, '-foyznsog': 1, 'Nz': 1, 'marpnys': 1, '“AAITRIN': 1, '“SaupNaS': 1, 'Unruenodosa': 1, 'y-ouhige': 1, 'BMquayiory': 1, 'sarpnyy': 1, 'ABOOIVIDAY': 1, 'URAUR.UAyIpapL': 1, '“UlLlag¢': 1, '“Bopopyat': 1, 'p': 1, 'vayasiyy': 1, 'ISDA': 1, 'NOL': 1, 'aiojaruliss': 1, 'yr': 1, 'MOY': 1, 'ieaypay': 1, '“PAOFROP': 1, 'HON,': 1, 'Tebg': 1, 'enayr': 1, 'Kbojommp': 1, 'pip': 1, 'cadop': 1, 'lige': 1, 'P4OLLO': 1, '1.661': 1, '(po)': 1, 'Wot': 1, 'Say': 1, 'UOPUOT': 1, '“pany': 1, 'Kr': 1, 'jn': 1, 'Kbojoanysap': 1, 'sof’': 1, 'MSUT': 1, 'YSU': 1, 'suounouqng': 1, 'POUOWNIIC)': 1, '“Ulpeg,': 1, 'Bunpazinjosyvy': 1, 'ayos': 1, 'Isrpojuaracy': 1, 'Wd': 1, 'AnarT': 1, '“Dapp': 1, 'THSUGE': 1, '(Naor': 1, 'D1.': 1, 'DPI': 1, 'WIR': 1, 'S400}': 1, '“HM,)': 1, '18': 1, 'seageg': 1, 'sanbibopoahiss': 1, '839])': 1, 'AUNOAT': 1, '“TO0%': 1, '“AM': 1, 'CUA': 1, 'Bunt ...
# 1612
# 535
# image idx:  1
# Page
# image idx:  2
# Page
# image idx:  3
# Page
# image idx:  4
# Page
# csv saved at /content/drive/My Drive/AWCA/Colab_notebooks/OCR/OCR_PDF2Page/180_output/1nw0k9Cj5HvFfF5JIgjgcZ_ci2DYCGHVR/page.csv

# %% [markdown]
# Ideas for orientation:
# (A represents a constant)
# - Compare the number of words for each of the orientations, and if one has Ax more than each of the others (A set to a constant), then use that one. Only works if orientations that are wrong output very low word counts.
# - Randomly select A documents and produce a unique list of all the words that appear in these pages. Then for each orientation, compare if it has enough overlap between the list and itself. Does not work for documents that are short. Use min(page count, 5, 0.1*doc length)
# - Same idea as #2, but take only the A most frequent words to put in the unique list. Then compare based on some logic statement similar to the one used previously.
